# %% [markdown]
# # Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import requests
import seaborn as sns
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
import warnings
warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# ## Reading all the data from their file location

# %%
#Importing the data and creating a dataframe
df = pd.read_excel(input("Enter path to the input Excel file: "))       # C:\Users\tusha\Downloads\Input.xlsx
# Out:
# Enter path to the input Excel file: C:\Users\tusha\Downloads\Input.xlsx

# %%
#getting the location of the folder where stopwords files are located
stopwords_folder = input("Enter path to the folder where stopwords files are located: ") #C:\Users\tusha\Downloads\StopWords
# Out:
# Enter path to the folder where stopwords files are located: C:\Users\tusha\Downloads\StopWords

# %%
#Giving the positive words and negative words file's location
positive_file_path = input("Enter path to the positive words file: ")   #C:\Users\tusha\Downloads\positive-words.txt
negative_file_path = input("Enter path to the negative words file: ")   #C:\Users\tusha\Downloads\negative-words.txt
# Out:
# Enter path to the positive words file: C:\Users\tusha\Downloads\positive-words.txt
# Enter path to the negative words file: C:\Users\tusha\Downloads\negative-words.txt

# %%
Output_File_Location = input("Enter path to the Output_Data_Structure excel file: ")  #C:\Users\tusha\Downloads\Output Data Structure.xlsx
# Out:
# Enter path to the Output_Data_Structure excel file: C:\Users\tusha\Downloads\Output Data Structure.xlsx

# %%
#To display the max rows and columns
pd.set_option('display.max_columns' , None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Fetching the content from the URLs

# %%
# Function to fetch text content for each URL
def fetch_content(url):
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            text_content = soup.get_text()
            return text_content
        else:
            print(f'Failed to fetch the content from URL: {url} | status_code: {response.status_code}')
            return None

# %%
# Add a new column 'content' to store text content for each URL
content = pd.DataFrame()
content['content'] = df['URL'].apply(lambda url: fetch_content(url))
content.reset_index(drop=True, inplace=True)
# Out:
# Failed to fetch the content from URL: https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/ | status_code: 404
# Failed to fetch the content from URL: https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/ | status_code: 404

# %%
content
# Out:
#                                               content
# 0   \n\n\n  \n\nRising IT cities and its impact on...
# 1   \n\n\n  \n\nRising IT Cities and Their Impact ...
# 2   \n\n\n  \n\nInternet Demand's Evolution, Commu...
# 3   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 4   \n\n\n  \n\nOTT platform and its impact on the...
# 5   \n\n\n  \n\nThe rise of the OTT platform and i...
# 6   \n\n\n  \n\nRise of Cyber Crime and its Effect...
# 7   \n\n\n  \n\nRise of Internet Demand and Its Im...
# 8   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 9   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 10  \n\n\n  \n\nRise of Internet Demand and its Im...
# 11  \n\n\n  \n\nRise of telemedicine and its Impac...
# 12  \n\n\n  \n\nRise of e-health and its impact on...
# 13  \n\n\n  \n\nRise of e-health and its impact on...
# 14  \n\n\n  \n\nRise of telemedicine and its Impac...
# 15  \n\n\n  \n\nRise of telemedicine and its Impac...
# 16  \n\n\n  \n\nRise of Chatbots and its impact on...
# 17  \n\n\n  \n\nRise of e-health and its impact on...
# 18  \n\n\n  \n\nHow does marketing influence busin...
# 19  \n\n\n  \n\nHow advertisement increase your ma...
# 20  \n\n\n  \n\nNegative effects of marketing on s...
# 21  \n\n\n  \n\nHow advertisement/marketing affect...
# 22  \n\n\n  \n\nRising IT cities will impact the e...
# 23  \n\n\n  \n\nRise of OTT platform and its impac...
# 24  \n\n\n  \n\nRise of Electric Vehicles and its ...
# 25  \n\n\n  \n\nRise of electric vehicle and its i...
# 26  \n\n\n  \n\nOil prices by the year 2040, and h...
# 27  \n\n\n  \n\nAn outlook of healthcare by the ye...
# 28  \n\n\n  \n\nAI in healthcare to Improve Patien...
# 29  \n\n\n  \n\nWhat if the Creation is Taking Ove...
# 30  \n\n\n  \n\nWhat Jobs Will Robots Take From Hu...
# 31  \n\n\n  \n\nWill Machine Replace The Human in ...
# 32  \n\n\n  \n\nWill AI Replace Us or Work With Us...
# 33  \n\n\n  \n\nWill machine replace the human in ...
# 34  \n\n\n  \n\nHow humans and machines are evolvi...
# 35                                               None
# 36  \n\n\n  \n\nHow machine learning will affect y...
# 37  \n\n\n  \n\nDeep learning impact on areas of e...
# 38  \n\n\n  \n\nHow to protect future data and its...
# 39  \n\n\n  \n\nHow Machines, AI, Automations, and...
# 40  \n\n\n  \n\nHow Robo Human will Impact the Fut...
# 41  \n\n\n  \n\nHow AI will change the World? - Bl...
# 42  \n\n\n  \n\nFuture of Work: How AI Has Entered...
# 43  \n\n\n  \n\nHow machine learning used in finan...
# 44  \n\n\n  \n\nHow AI will impact the future of w...
# 45  \n\n\n  \n\nAll you need to know about online ...
# 46  \n\n\n  \n\nEvolution of Advertising Industry ...
# 47  \n\n\n  \n\nHow Data Analytics can help your b...
# 48                                               None
# 49  \n\n\n  \n\nEnvironmental impact of the COVID-...
# 50  \n\n\n  \n\nHow Data Analytics and AI are used...
# 51  \n\n\n  \n\nAI Machine Learning Statistics and...
# 52  \n\n\n  \n\nPython became the choice for Data ...
# 53  \n\n\n  \n\nGoogle fit measure heart and respi...
# 54  \n\n\n  \n\nmobile apps - Future | blackcoffer...
# 55  \n\n\n  \n\nAI in health and medicine | impact...
# 56  \n\n\n  \n\ntelemedicine - What patients like ...
# 57  \n\n\n  \n\nforecast future technologies- how ...
# 58  \n\n\n  \n\nCan robots tackle life loneliness ...
# 59  \n\n\n  \n\nSocio-technical considerations - E...
# 60  \n\n\n  \n\nfuture digitalization of healthcar...
# 61  \n\n\n  \n\nAre we any closer to preventing a ...
# 62  \n\n\n  \n\nWill technology eliminate the need...
# 63  \n\n\n  \n\nWill we ever understand the nature...
# 64  \n\n\n  \n\nWill we ever colonize outer space?...
# 65  \n\n\n  \n\nWhat is the chance Homo sapiens wi...
# 66  \n\n\n  \n\nWhy does your business need a chat...
# 67  \n\n\n  \n\nHow you lead a project or a team w...
# 68  \n\n\n  \n\nCan You Be Great Leader Without Te...
# 69  \n\n\n  \n\nHow does artificial intelligence a...
# 70  \n\n\n  \n\nHow to Overcome Your Fear of Makin...
# 71  \n\n\n  \n\nIs Perfection the Greatest enemy o...
# 72  \n\n\n  \n\nGlobal financial crisis 2008 cause...
# 73  \n\n\n  \n\nGender diversity and Equality in t...
# 74  \n\n\n  \n\nHow to overcome your fear of makin...
# 75  \n\n\n  \n\nHow Small Business can survive the...
# 76  \n\n\n  \n\nImpacts of COVID 19 on Food produc...
# 77  \n\n\n  \n\nImpacts of COVID 19 on Vegetable V...
# 78  \n\n\n  \n\nImpact of COVID-19 pandemic on Tou...
# 79  \n\n\n  \n\nImpact of COVID-19 pandemic on spo...
# 80  \n\n\n  \n\nChanging landscape and emerging tr...
# 81  \n\n\n  \n\nOnline gaming: Adolescent online g...
# 82  \n\n\n  \n\nHuman Rights Outlook - Blackcoffer...
# 83  \n\n\n  \n\nHow Voice search makes your busine...
# 84  \n\n\n  \n\nHow the COVID-19 crisis is redefin...
# 85  \n\n\n  \n\nHow to increase social media engag...
# 86  \n\n\n  \n\nImpacts of COVID 19 on Streets Sid...
# 87  \n\n\n  \n\nCoronavirus impact on energy marke...
# 88  \n\n\n  \n\nCOVID-19 Impact on Hospitality Ind...
# 89  \n\n\n  \n\nkey learnings relevant to the coro...
# 90  \n\n\n  \n\nEstimating the impact of COVID-19 ...
# 91  \n\n\n  \n\nEstimating the impact of COVID-19 ...
# 92  \n\n\n  \n\nTravel and Tourism Outlook - Black...
# 93  \n\n\n  \n\nGaming Disorder and Effects of Gam...
# 94  \n\n\n  \n\nWhat is the repercussion of the en...
# 95  \n\n\n  \n\nDue to the COVID-19 the repercussi...
# 96  \n\n\n  \n\nImpact of COVID-19 pandemic on off...
# 97  \n\n\n  \n\nContribution of handicrafts (Visua...
# 98  \n\n\n  \n\nHow COVID-19 is impacting payment ...
# 99  \n\n\n  \n\nHow will COVID-19 affect the world...

# %% [markdown]
# # Sentimental Analysis

# %%
stopwords_files = []
for name in ["Generic", "Auditor", "Currencies", "DatesandNumbers", "GenericLong", "Geographic", "Names"]:
    # Construct the file path by concatenating folder path and filename
    stopwords_file = f"{stopwords_folder}\\StopWords_{name}.txt"
    stopwords_files.append(stopwords_file)

# %%
stopwords = pd.DataFrame()  # Initialize an empty DataFrame
for file in stopwords_files:
    if "Currencies" in file:
        # For StopWords_Currencies file
        df_temp = pd.read_csv(file, sep='|', encoding='latin-1', header=None)  
        # Concatenate both columns on axis=0
        df_temp = pd.concat([df_temp[0], df_temp[1]], axis=0, ignore_index=True)
        stopwords = pd.concat([stopwords, df_temp], ignore_index=True, axis=0)  # Assign the result back to dfs
    elif "DatesandNumbers" in file or "Geographic" in file or "Names" in file:
        # For StopWords_DatesandNumbers, StopWords_Geographic, and StopWords_Names files
        df_temp = pd.read_csv(file, header=None, sep='|', usecols=[0])  
        stopwords = pd.concat([stopwords, df_temp], ignore_index=True, axis=0)  # Assign the result back to dfs
    elif "Generic" in file or "Auditor" in file or "GenericLong" in file:
        df_temp = pd.read_csv(file, header=None)  
        stopwords = pd.concat([stopwords, df_temp], ignore_index=True, axis=0)  # Assign the result back to dfs

# %%
#creating a list of lowercase stopwords
stopwords_list = []
for word in stopwords[0]:
    if not pd.isna(word):  # Check if the value is not NaN
        stopwords_list.append(word.lower())

# %%
stopwords_list
# Out:
# ['about',
#  'above',
#  'after',
#  'again',
#  'all',
#  'am',
#  'among',
#  'an',
#  'and',
#  'any',
#  'are',
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'has',
#  'have',
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'if',
#  'in',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'me',
#  'more',
#  'most',
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'now',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'same',
#  'she',
#  'should',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  'we',
#  'were',
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'with',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'ernst',
#  'young',
#  'deloitte',
#  'touche',
#  'kpmg',
#  'pricewaterhousecoopers',
#  'pricewaterhouse',
#  'coopers',
#  'afghani  ',
#  'ariary ',
#  'baht ',
#  'balboa ',
#  'birr ',
#  'bolivar ',
#  'boliviano  ',
#  'cedi ',
#  'colon  ',
#  'córdoba  ',
#  'dalasi ',
#  'denar ',
#  'dinar ',
#  'dirham  ',
#  'dobra ',
#  'dong ',
#  'dram ',
#  'escudo  ',
#  'euro  ',
#  'florin ',
#  'forint ',
#  'gourde ',
#  'guarani ',
#  'gulden ',
#  'hryvnia  ',
#  'kina ',
#  'kip ',
#  'konvertibilna marka  ',
#  'koruna  ',
#  'krona ',
#  'krone ',
#  'kroon ',
#  'kuna ',
#  'kwacha ',
#  'kwanza ',
#  'kyat ',
#  'lari ',
#  'lats ',
#  'lek ',
#  'lempira ',
#  'leone ',
#  'leu ',
#  'lev ',
#  'lilangeni  ',
#  'lira ',
#  'litas ',
#  'loti ',
#  'manat ',
#  'metical ',
#  'naira ',
#  'nakfa ',
#  'new lira ',
#  'new sheqel  ',
#  'ngultrum  ',
#  'nuevo sol ',
#  'ouguiya  ',
#  'pataca ',
#  'peso  ',
#  'pound  ',
#  'pula  ',
#  'quetzal ',
#  'rand ',
#  'real  ',
#  'renminbi  ',
#  'rial ',
#  'riel ',
#  'ringgit ',
#  'riyal ',
#  'ruble ',
#  'rufiyaa ',
#  'rupee  ',
#  'rupee  ',
#  'rupiah  ',
#  'shilling  ',
#  'som ',
#  'somoni  ',
#  'special drawing rights  ',
#  'taka ',
#  'tala ',
#  'tenge ',
#  'tugrik  ',
#  'vatu ',
#  'won  ',
#  'yen ',
#  'zloty ',
#  ' afghanistan ',
#  ' madagascar ',
#  ' thailand ',
#  ' panama ',
#  ' ethiopia ',
#  ' venezuela ',
#  ' bolivia ',
#  ' ghana ',
#  ' costa rica ',
#  ' nicaragua ',
#  ' gambia ',
#  ' macedonia (former yug. rep.) ',
#  ' algeria ',
#  ' morocco ',
#  ' são tom and príncipe ',
#  ' vietnam ',
#  ' armenia ',
#  ' cape verde ',
#  ' belgium ',
#  ' aruba ',
#  ' hungary ',
#  ' haiti ',
#  ' paraguay ',
#  ' netherlands antilles ',
#  ' ukraine ',
#  ' papua new guinea ',
#  ' laos ',
#  ' bosnia-herzegovina ',
#  ' czech republic ',
#  ' sweden ',
#  ' denmark ',
#  ' estonia ',
#  ' croatia ',
#  ' zambia ',
#  ' angola ',
#  ' myanmar ',
#  ' georgia ',
#  ' latvia ',
#  ' albania ',
#  ' honduras ',
#  ' sierra leone ',
#  ' romania ',
#  ' bulgaria ',
#  ' swaziland ',
#  ' lebanon ',
#  ' lithuania ',
#  ' lesotho ',
#  ' azerbaijan ',
#  ' mozambique ',
#  ' nigeria ',
#  ' eritrea ',
#  ' turkey ',
#  ' israel ',
#  ' bhutan ',
#  ' peru ',
#  ' mauritania ',
#  ' macau ',
#  ' mexico ',
#  ' egypt ',
#  ' botswana ',
#  ' guatemala ',
#  ' south africa ',
#  ' brazil ',
#  ' china ',
#  ' iran ',
#  ' cambodia ',
#  ' malaysia ',
#  ' saudi arabia ',
#  ' russia ',
#  ' maldives ',
#  ' india ',
#  ' pakistan ',
#  ' indonesia ',
#  ' uganda ',
#  ' uzbekistan ',
#  ' tajikistan ',
#  ' international monetary fund ',
#  ' bangladesh ',
#  ' western samoa ',
#  ' kazakhstan ',
#  ' mongolia ',
#  ' vanuatu ',
#  ' korea, south ',
#  ' japan ',
#  ' poland ',
#  'hundred  ',
#  'thousand',
#  'million',
#  'billion',
#  'trillion',
#  'date  ',
#  'annual',
#  'annually',
#  'annum',
#  'year',
#  'yearly',
#  'quarter',
#  'quarterly',
#  'qtr',
#  'month',
#  'monthly',
#  'week',
#  'weekly',
#  'day',
#  'daily',
#  'january  ',
#  'february',
#  'march',
#  'april',
#  'may',
#  'june',
#  'july',
#  'august',
#  'september',
#  'october',
#  'november',
#  'december',
#  'jan',
#  'feb',
#  'mar',
#  'apr',
#  'may',
#  'jun',
#  'jul',
#  'aug',
#  'sep',
#  'sept',
#  'oct',
#  'nov',
#  'dec',
#  'monday',
#  'tuesday',
#  'wednesday',
#  'thursday',
#  'friday',
#  'saturday',
#  'sunday',
#  'one  ',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'eleven',
#  'twelve',
#  'thirteen',
#  'fourteen',
#  'fifteen',
#  'sixteen',
#  'seventeen',
#  'eighteen',
#  'nineteen',
#  'twenty',
#  'thirty',
#  'forty',
#  'fifty',
#  'sixty',
#  'seventy',
#  'eighty',
#  'ninety',
#  'first',
#  'second',
#  'third',
#  'fourth',
#  'fifth',
#  'sixth',
#  'seventh',
#  'eighth',
#  'ninth',
#  'tenth',
#  'i  ',
#  'ii',
#  'iii',
#  'iv',
#  'v',
#  'vi',
#  'vii',
#  'viii',
#  'ix',
#  'x',
#  'xi',
#  'xii',
#  'xiii',
#  'xiv',
#  'xv',
#  'xvi',
#  'xvii',
#  'xviii',
#  'xix',
#  'xx',
#  'a',
#  "a's",
#  'able',
#  'about',
#  'above',
#  'according',
#  'accordingly',
#  'across',
#  'actually',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  "ain't",
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apart',
#  'appear',
#  'appreciate',
#  'appropriate',
#  'are',
#  "aren't",
#  'around',
#  'as',
#  'aside',
#  'ask',
#  'asking',
#  'associated',
#  'at',
#  'available',
#  'away',
#  'awfully',
#  'b',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'believe',
#  'below',
#  'beside',
#  'besides',
#  'best',
#  'better',
#  'between',
#  'beyond',
#  'both',
#  'brief',
#  'but',
#  'by',
#  'c',
#  "c'mon",
#  "c's",
#  'came',
#  'can',
#  "can't",
#  'cannot',
#  'cant',
#  'cause',
#  'causes',
#  'certain',
#  'certainly',
#  'changes',
#  'clearly',
#  'co',
#  'com',
#  'come',
#  'comes',
#  'concerning',
#  'consequently',
#  'consider',
#  'considering',
#  'contain',
#  'containing',
#  'contains',
#  'corresponding',
#  'could',
#  "couldn't",
#  'course',
#  'currently',
#  'd',
#  'definitely',
#  'described',
#  'despite',
#  'did',
#  "didn't",
#  'different',
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'done',
#  'down',
#  'downwards',
#  'during',
#  'e',
#  'each',
#  'edu',
#  'eg',
#  'eight',
#  'either',
#  'else',
#  'elsewhere',
#  'enough',
#  'entirely',
#  'especially',
#  'et',
#  'etc',
#  'even',
#  'ever',
#  'every',
#  'everybody',
#  'everyone',
#  'everything',
#  'everywhere',
#  'ex',
#  'exactly',
#  'example',
#  'except',
#  'f',
#  'far',
#  'few',
#  'fifth',
#  'first',
#  'five',
#  'followed',
#  'following',
#  'follows',
#  'for',
#  'former',
#  'formerly',
#  'forth',
#  'four',
#  'from',
#  'further',
#  'furthermore',
#  'g',
#  'get',
#  'gets',
#  'getting',
#  'given',
#  'gives',
#  'go',
#  'goes',
#  'going',
#  'gone',
#  'got',
#  'gotten',
#  'greetings',
#  'h',
#  'had',
#  "hadn't",
#  'happens',
#  'hardly',
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he's",
#  'hello',
#  'help',
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'hi',
#  'him',
#  'himself',
#  'his',
#  'hither',
#  'hopefully',
#  'how',
#  'howbeit',
#  'however',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'ie',
#  'if',
#  'ignored',
#  'immediate',
#  'in',
#  'inasmuch',
#  'inc',
#  'indeed',
#  'indicate',
#  'indicated',
#  'indicates',
#  'inner',
#  'insofar',
#  'instead',
#  'into',
#  'inward',
#  'is',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'j',
#  'just',
#  'k',
#  'keep',
#  'keeps',
#  'kept',
#  'know',
#  'knows',
#  'known',
#  'l',
#  'last',
#  'lately',
#  'later',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'lest',
#  'let',
#  "let's",
#  'like',
#  'liked',
#  'likely',
#  'little',
#  'look',
#  'looking',
#  'looks',
#  'ltd',
#  'm',
#  'mainly',
#  'many',
#  'may',
#  'maybe',
#  'me',
#  'mean',
#  'meanwhile',
#  'merely',
#  'might',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'much',
#  'must',
#  'my',
#  'myself',
#  'n',
#  'name',
#  'namely',
#  'nd',
#  'near',
#  'nearly',
#  'necessary',
#  'need',
#  'needs',
#  'neither',
#  'never',
#  'nevertheless',
#  'new',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'non',
#  'none',
#  'noone',
#  'nor',
#  'normally',
#  'not',
#  'nothing',
#  'novel',
#  'now',
#  'nowhere',
#  'o',
#  'obviously',
#  'of',
#  'off',
#  'often',
#  'oh',
#  'ok',
#  'okay',
#  'old',
#  'on',
#  'once',
#  'one',
#  'ones',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'outside',
#  'over',
#  'overall',
#  'own',
#  'p',
#  'particular',
#  'particularly',
#  'per',
#  'perhaps',
#  'placed',
#  'please',
#  'plus',
#  'possible',
#  'presumably',
#  'probably',
#  'provides',
#  'q',
#  'que',
#  'quite',
#  'qv',
#  'r',
#  'rather',
#  'rd',
#  're',
#  'really',
#  'reasonably',
#  'regarding',
#  'regardless',
#  'regards',
#  'relatively',
#  'respectively',
#  'right',
#  's',
#  'said',
#  'same',
#  'saw',
#  'say',
#  'saying',
#  'says',
#  'second',
#  'secondly',
#  'see',
#  'seeing',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'seen',
#  'self',
#  'selves',
#  'sensible',
#  'sent',
#  'serious',
#  'seriously',
#  'seven',
#  'several',
#  'shall',
#  'she',
#  'should',
#  "shouldn't",
#  'since',
#  'six',
#  'so',
#  'some',
#  'somebody',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhat',
#  'somewhere',
#  'soon',
#  'sorry',
#  'specified',
#  'specify',
#  'specifying',
#  'still',
#  'sub',
#  'such',
#  'sup',
#  'sure',
#  't',
#  "t's",
#  'take',
#  'taken',
#  'tell',
#  'tends',
#  'th',
#  'than',
#  'thank',
#  'thanks',
#  'thanx',
#  'that',
#  "that's",
#  'thats',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  "there's",
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'theres',
#  'thereupon',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'think',
#  'third',
#  'this',
#  'thorough',
#  'thoroughly',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'took',
#  'toward',
#  'towards',
#  'tried',
#  'tries',
#  'truly',
#  'try',
#  'trying',
#  'twice',
#  'two',
#  'u',
#  'un',
#  'under',
#  'unfortunately',
#  'unless',
#  'unlikely',
#  'until',
#  'unto',
#  'up',
#  'upon',
#  'us',
#  'use',
#  'used',
#  'useful',
#  'uses',
#  'using',
#  'usually',
#  'uucp',
#  'v',
#  'value',
#  'various',
#  'very',
#  'via',
#  'viz',
#  'vs',
#  'w',
#  'want',
#  'wants',
#  'was',
#  "wasn't",
#  'way',
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'welcome',
#  'well',
#  'went',
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  "where's",
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  "who's",
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'willing',
#  'wish',
#  'with',
#  'within',
#  'without',
#  "won't",
#  'wonder',
#  'would',
#  'would',
#  "wouldn't",
#  'x',
#  'y',
#  'yes',
#  'yet',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'z',
#  'zero',
#  'united  ',
#  'state',
#  'north',
#  'south',
#  'east',
#  'northeast',
#  'northwest',
#  'southeast',
#  'southwest',
#  'west',
#  'ocean',
#  'sea',
#  'lake',
#  'river',
#  'creek',
#  'gulf',
#  'mountain',
#  'street',
#  'boulevard',
#  'blvd',
#  'parkway',
#  ...]

# %% [markdown]
# ## Tokenizing the content extracted from URLs

# %%
content['content'] = content['content'].astype(str)
content['token'] = content['content'].apply(lambda x:word_tokenize(x))

# %% [markdown]
# ## Cleaning using Stop Words Lists

# %%
content['token'] = content['token'].apply(lambda x: [i.lower() for i in x])

# %%
content['text'] = content['token'].apply(lambda x: [word for word in x if word not in stopwords_list])
content.drop(columns=['token'], inplace=True)

# %%
content['new_text'] = content['text'].apply(lambda x: [re.sub(r'[^\w\s]', '', word) for word in x])
content['clean_text']  = content['new_text'].apply(lambda x:[word for word in x if word != ''])

# %%
content.drop(columns = ['text','new_text'], inplace =True)

# %%
content
# Out:
#                                               content  \
# 0   \n\n\n  \n\nRising IT cities and its impact on...
# 1   \n\n\n  \n\nRising IT Cities and Their Impact ...
# 2   \n\n\n  \n\nInternet Demand's Evolution, Commu...
# 3   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 4   \n\n\n  \n\nOTT platform and its impact on the...
# 5   \n\n\n  \n\nThe rise of the OTT platform and i...
# 6   \n\n\n  \n\nRise of Cyber Crime and its Effect...
# 7   \n\n\n  \n\nRise of Internet Demand and Its Im...
# 8   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 9   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 10  \n\n\n  \n\nRise of Internet Demand and its Im...
# 11  \n\n\n  \n\nRise of telemedicine and its Impac...
# 12  \n\n\n  \n\nRise of e-health and its impact on...
# 13  \n\n\n  \n\nRise of e-health and its impact on...
# 14  \n\n\n  \n\nRise of telemedicine and its Impac...
# 15  \n\n\n  \n\nRise of telemedicine and its Impac...
# 16  \n\n\n  \n\nRise of Chatbots and its impact on...
# 17  \n\n\n  \n\nRise of e-health and its impact on...
# 18  \n\n\n  \n\nHow does marketing influence busin...
# 19  \n\n\n  \n\nHow advertisement increase your ma...
# 20  \n\n\n  \n\nNegative effects of marketing on s...
# 21  \n\n\n  \n\nHow advertisement/marketing affect...
# 22  \n\n\n  \n\nRising IT cities will impact the e...
# 23  \n\n\n  \n\nRise of OTT platform and its impac...
# 24  \n\n\n  \n\nRise of Electric Vehicles and its ...
# 25  \n\n\n  \n\nRise of electric vehicle and its i...
# 26  \n\n\n  \n\nOil prices by the year 2040, and h...
# 27  \n\n\n  \n\nAn outlook of healthcare by the ye...
# 28  \n\n\n  \n\nAI in healthcare to Improve Patien...
# 29  \n\n\n  \n\nWhat if the Creation is Taking Ove...
# 30  \n\n\n  \n\nWhat Jobs Will Robots Take From Hu...
# 31  \n\n\n  \n\nWill Machine Replace The Human in ...
# 32  \n\n\n  \n\nWill AI Replace Us or Work With Us...
# 33  \n\n\n  \n\nWill machine replace the human in ...
# 34  \n\n\n  \n\nHow humans and machines are evolvi...
# 35                                               None
# 36  \n\n\n  \n\nHow machine learning will affect y...
# 37  \n\n\n  \n\nDeep learning impact on areas of e...
# 38  \n\n\n  \n\nHow to protect future data and its...
# 39  \n\n\n  \n\nHow Machines, AI, Automations, and...
# 40  \n\n\n  \n\nHow Robo Human will Impact the Fut...
# 41  \n\n\n  \n\nHow AI will change the World? - Bl...
# 42  \n\n\n  \n\nFuture of Work: How AI Has Entered...
# 43  \n\n\n  \n\nHow machine learning used in finan...
# 44  \n\n\n  \n\nHow AI will impact the future of w...
# 45  \n\n\n  \n\nAll you need to know about online ...
# 46  \n\n\n  \n\nEvolution of Advertising Industry ...
# 47  \n\n\n  \n\nHow Data Analytics can help your b...
# 48                                               None
# 49  \n\n\n  \n\nEnvironmental impact of the COVID-...
# 50  \n\n\n  \n\nHow Data Analytics and AI are used...
# 51  \n\n\n  \n\nAI Machine Learning Statistics and...
# 52  \n\n\n  \n\nPython became the choice for Data ...
# 53  \n\n\n  \n\nGoogle fit measure heart and respi...
# 54  \n\n\n  \n\nmobile apps - Future | blackcoffer...
# 55  \n\n\n  \n\nAI in health and medicine | impact...
# 56  \n\n\n  \n\ntelemedicine - What patients like ...
# 57  \n\n\n  \n\nforecast future technologies- how ...
# 58  \n\n\n  \n\nCan robots tackle life loneliness ...
# 59  \n\n\n  \n\nSocio-technical considerations - E...
# 60  \n\n\n  \n\nfuture digitalization of healthcar...
# 61  \n\n\n  \n\nAre we any closer to preventing a ...
# 62  \n\n\n  \n\nWill technology eliminate the need...
# 63  \n\n\n  \n\nWill we ever understand the nature...
# 64  \n\n\n  \n\nWill we ever colonize outer space?...
# 65  \n\n\n  \n\nWhat is the chance Homo sapiens wi...
# 66  \n\n\n  \n\nWhy does your business need a chat...
# 67  \n\n\n  \n\nHow you lead a project or a team w...
# 68  \n\n\n  \n\nCan You Be Great Leader Without Te...
# 69  \n\n\n  \n\nHow does artificial intelligence a...
# 70  \n\n\n  \n\nHow to Overcome Your Fear of Makin...
# 71  \n\n\n  \n\nIs Perfection the Greatest enemy o...
# 72  \n\n\n  \n\nGlobal financial crisis 2008 cause...
# 73  \n\n\n  \n\nGender diversity and Equality in t...
# 74  \n\n\n  \n\nHow to overcome your fear of makin...
# 75  \n\n\n  \n\nHow Small Business can survive the...
# 76  \n\n\n  \n\nImpacts of COVID 19 on Food produc...
# 77  \n\n\n  \n\nImpacts of COVID 19 on Vegetable V...
# 78  \n\n\n  \n\nImpact of COVID-19 pandemic on Tou...
# 79  \n\n\n  \n\nImpact of COVID-19 pandemic on spo...
# 80  \n\n\n  \n\nChanging landscape and emerging tr...
# 81  \n\n\n  \n\nOnline gaming: Adolescent online g...
# 82  \n\n\n  \n\nHuman Rights Outlook - Blackcoffer...
# 83  \n\n\n  \n\nHow Voice search makes your busine...
# 84  \n\n\n  \n\nHow the COVID-19 crisis is redefin...
# 85  \n\n\n  \n\nHow to increase social media engag...
# 86  \n\n\n  \n\nImpacts of COVID 19 on Streets Sid...
# 87  \n\n\n  \n\nCoronavirus impact on energy marke...
# 88  \n\n\n  \n\nCOVID-19 Impact on Hospitality Ind...
# 89  \n\n\n  \n\nkey learnings relevant to the coro...
# 90  \n\n\n  \n\nEstimating the impact of COVID-19 ...
# 91  \n\n\n  \n\nEstimating the impact of COVID-19 ...
# 92  \n\n\n  \n\nTravel and Tourism Outlook - Black...
# 93  \n\n\n  \n\nGaming Disorder and Effects of Gam...
# 94  \n\n\n  \n\nWhat is the repercussion of the en...
# 95  \n\n\n  \n\nDue to the COVID-19 the repercussi...
# 96  \n\n\n  \n\nImpact of COVID-19 pandemic on off...
# 97  \n\n\n  \n\nContribution of handicrafts (Visua...
# 98  \n\n\n  \n\nHow COVID-19 is impacting payment ...
# 99  \n\n\n  \n\nHow will COVID-19 affect the world...
#
#                                            clean_text
# 0   [rising, cities, impact, economy, environment,...
# 1   [rising, cities, impact, economy, environment,...
# 2   [internet, demand, s, evolution, communication...
# 3   [rise, cybercrime, effect, upcoming, future, b...
# 4   [platform, impact, entertainment, industry, fu...
# 5   [rise, platform, impact, entertainment, indust...
# 6   [rise, cyber, crime, effects, blackcoffer, ins...
# 7   [rise, internet, demand, impact, communication...
# 8   [rise, cybercrime, effect, 2040, blackcoffer, ...
# 9   [rise, cybercrime, effect, 2040, blackcoffer, ...
# 10  [rise, internet, demand, impact, communication...
# 11  [rise, telemedicine, impact, livelihood, 2040,...
# 12  [rise, ehealth, impact, humans, 2030, blackcof...
# 13  [rise, ehealth, impact, humans, 2030, blackcof...
# 14  [rise, telemedicine, impact, livelihood, 2040,...
# 15  [rise, telemedicine, impact, livelihood, 2040,...
# 16  [rise, chatbots, impact, customer, support, 20...
# 17  [rise, ehealth, impact, humans, 2030, blackcof...
# 18  [marketing, influence, businesses, consumers, ...
# 19  [advertisement, increase, market, blackcoffer,...
# 20  [negative, effects, marketing, society, blackc...
# 21  [advertisementmarketing, affects, business, bl...
# 22  [rising, cities, impact, economy, environment,...
# 23  [rise, platform, impact, entertainment, indust...
# 24  [rise, electric, vehicles, impact, livelihood,...
# 25  [rise, electric, vehicle, impact, livelihood, ...
# 26  [oil, prices, 2040, impact, world, economy, bl...
# 27  [outlook, healthcare, 2040, impact, human, liv...
# 28  [healthcare, improve, patient, outcomes, black...
# 29  [creation, taking, creator, blackcoffer, insig...
# 30  [jobs, robots, humans, future, blackcoffer, in...
# 31  [machine, replace, human, future, work, blackc...
# 32  [replace, work, blackcoffer, insights, sign, s...
# 33  [machine, replace, human, future, work, blackc...
# 34  [humans, machines, evolving, work, blackcoffer...
# 35                                                 []
# 36  [machine, learning, affect, business, blackcof...
# 37  [deep, learning, impact, areas, elearning, bla...
# 38  [protect, future, data, privacy, blackcoffer, ...
# 39  [machines, automations, robohuman, effective, ...
# 40  [robo, human, impact, future, blackcoffer, ins...
# 41  [change, world, blackcoffer, insights, sign, s...
# 42  [future, work, entered, workplace, blackcoffer...
# 43  [machine, learning, finance, banking, blackcof...
# 44  [impact, future, work, blackcoffer, insights, ...
# 45  [online, marketing, blackcoffer, insights, sig...
# 46  [evolution, advertising, industry, blackcoffer...
# 47  [data, analytics, business, respond, impact, c...
# 48                                                 []
# 49  [environmental, impact, covid19, pandemic, les...
# 50  [data, analytics, halt, covid19, pandemic, bla...
# 51  [machine, learning, statistics, data, mining, ...
# 52  [python, choice, data, science, s, sign, succe...
# 53  [google, fit, measure, heart, respiratory, rat...
# 54  [mobile, apps, future, blackcoffer, insights, ...
# 55  [health, medicine, impact, blackcoffer, insigh...
# 56  [telemedicine, patients, dislike, blackcoffer,...
# 57  [forecast, future, technologies, blackcoffer, ...
# 58  [robots, tackle, life, loneliness, blackcoffer...
# 59  [sociotechnical, considerations, embedding, ca...
# 60  [future, digitalization, healthcare, services,...
# 61  [closer, preventing, nuclear, holocaust, black...
# 62  [technology, eliminate, animal, testing, drug,...
# 63  [understand, nature, consciousness, blackcoffe...
# 64  [colonize, outer, space, blackcoffer, insights...
# 65  [homo, sapiens, survive, 500, years, blackcoff...
# 66  [business, chatbot, blackcoffer, insights, sig...
# 67  [lead, project, team, technical, expertise, bl...
# 68  [great, leader, technical, expertise, blackcof...
# 69  [artificial, intelligence, affect, environment...
# 70  [overcome, fear, making, mistakes, blackcoffer...
# 71  [perfection, greatest, enemy, productivity, bl...
# 72  [global, financial, crisis, 2008, causeseffect...
# 73  [gender, diversity, equality, tech, industry, ...
# 74  [overcome, fear, making, mistakes, blackcoffer...
# 75  [business, survive, coronavirus, crisis, black...
# 76  [impacts, covid, 19, food, products, blackcoff...
# 77  [impacts, covid, 19, vegetable, vendors, black...
# 78  [impact, covid19, pandemic, tourism, aviation,...
# 79  [impact, covid19, pandemic, sports, events, wo...
# 80  [changing, landscape, emerging, trends, itites...
# 81  [online, gaming, adolescent, online, gaming, e...
# 82  [human, rights, outlook, blackcoffer, insights...
# 83  [voice, search, makes, business, successful, b...
# 84  [covid19, crisis, redefining, jobs, services, ...
# 85  [increase, social, media, engagement, marketer...
# 86  [impacts, covid, 19, streets, food, stalls, bl...
# 87  [coronavirus, impact, energy, markets, blackco...
# 88  [covid19, impact, hospitality, industrty, blac...
# 89  [learnings, relevant, coronavirus, crisis, les...
# 90  [estimating, impact, covid19, world, work, bla...
# 91  [estimating, impact, covid19, world, work, bla...
# 92  [travel, tourism, outlook, blackcoffer, insigh...
# 93  [gaming, disorder, effects, gaming, health, bl...
# 94  [repercussion, environment, due, covid19, pand...
# 95  [due, covid19, repercussion, environment, blac...
# 96  [impact, covid19, pandemic, office, space, cow...
# 97  [contribution, handicrafts, visual, arts, lite...
# 98  [covid19, impacting, payment, preferences, bla...
# 99  [covid19, affect, world, work, blackcoffer, in...

# %% [markdown]
# ## Creating a dictionary of Positive and Negative words

# %%
positive = pd.read_csv(positive_file_path, header=None)
negative = pd.read_csv(negative_file_path, header=None, encoding='latin-1')

# %%
positive_dictonary = [words for words in positive[0] if words not in stopwords_list]
negative_dictonary = [words for words in negative[0] if words not in stopwords_list]

# %% [markdown]
# ### Extracting Derived variables

# %%
def positive_score(row, dictionary):
    Positive_Score = 0
    for word in row:
        if word in dictionary:
            Positive_Score += 1
    return Positive_Score

# %%
def negative_score(row,dictonary):
    Negative_Score = 0
    for word in row:
        if word in dictonary:
            Negative_Score -= 1
        else:
            pass
    return Negative_Score*-1

# %%
def polarity_score(p_score,n_score):
    Polarity_Score = (p_score - n_score) / ((p_score + n_score) + 0.000001)
    return Polarity_Score

# %%
def subjectivity_score(text,p_score,n_score):
    Subjectivity_Score = (p_score + n_score)/ ((len(text)) + 0.000001)
    return Subjectivity_Score

# %%
content['Positive_Score'] = content['clean_text'].apply(lambda x : positive_score(x, positive_dictonary))

# %%
content['Negative_score'] = content['clean_text'].apply(lambda x : negative_score(x, negative_dictonary))

# %%
content['Polarity_Score'] = content.apply(lambda row: polarity_score(row['Positive_Score'], row['Negative_score']), axis=1)

# %%
content['Subjectivity_Score'] = content.apply(lambda row: subjectivity_score(row['clean_text'],row['Positive_Score'], row['Negative_score']), axis=1)

# %%
content
# Out:
#                                               content  \
# 0   \n\n\n  \n\nRising IT cities and its impact on...
# 1   \n\n\n  \n\nRising IT Cities and Their Impact ...
# 2   \n\n\n  \n\nInternet Demand's Evolution, Commu...
# 3   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 4   \n\n\n  \n\nOTT platform and its impact on the...
# 5   \n\n\n  \n\nThe rise of the OTT platform and i...
# 6   \n\n\n  \n\nRise of Cyber Crime and its Effect...
# 7   \n\n\n  \n\nRise of Internet Demand and Its Im...
# 8   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 9   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 10  \n\n\n  \n\nRise of Internet Demand and its Im...
# 11  \n\n\n  \n\nRise of telemedicine and its Impac...
# 12  \n\n\n  \n\nRise of e-health and its impact on...
# 13  \n\n\n  \n\nRise of e-health and its impact on...
# 14  \n\n\n  \n\nRise of telemedicine and its Impac...
# 15  \n\n\n  \n\nRise of telemedicine and its Impac...
# 16  \n\n\n  \n\nRise of Chatbots and its impact on...
# 17  \n\n\n  \n\nRise of e-health and its impact on...
# 18  \n\n\n  \n\nHow does marketing influence busin...
# 19  \n\n\n  \n\nHow advertisement increase your ma...
# 20  \n\n\n  \n\nNegative effects of marketing on s...
# 21  \n\n\n  \n\nHow advertisement/marketing affect...
# 22  \n\n\n  \n\nRising IT cities will impact the e...
# 23  \n\n\n  \n\nRise of OTT platform and its impac...
# 24  \n\n\n  \n\nRise of Electric Vehicles and its ...
# 25  \n\n\n  \n\nRise of electric vehicle and its i...
# 26  \n\n\n  \n\nOil prices by the year 2040, and h...
# 27  \n\n\n  \n\nAn outlook of healthcare by the ye...
# 28  \n\n\n  \n\nAI in healthcare to Improve Patien...
# 29  \n\n\n  \n\nWhat if the Creation is Taking Ove...
# 30  \n\n\n  \n\nWhat Jobs Will Robots Take From Hu...
# 31  \n\n\n  \n\nWill Machine Replace The Human in ...
# 32  \n\n\n  \n\nWill AI Replace Us or Work With Us...
# 33  \n\n\n  \n\nWill machine replace the human in ...
# 34  \n\n\n  \n\nHow humans and machines are evolvi...
# 35                                               None
# 36  \n\n\n  \n\nHow machine learning will affect y...
# 37  \n\n\n  \n\nDeep learning impact on areas of e...
# 38  \n\n\n  \n\nHow to protect future data and its...
# 39  \n\n\n  \n\nHow Machines, AI, Automations, and...
# 40  \n\n\n  \n\nHow Robo Human will Impact the Fut...
# 41  \n\n\n  \n\nHow AI will change the World? - Bl...
# 42  \n\n\n  \n\nFuture of Work: How AI Has Entered...
# 43  \n\n\n  \n\nHow machine learning used in finan...
# 44  \n\n\n  \n\nHow AI will impact the future of w...
# 45  \n\n\n  \n\nAll you need to know about online ...
# 46  \n\n\n  \n\nEvolution of Advertising Industry ...
# 47  \n\n\n  \n\nHow Data Analytics can help your b...
# 48                                               None
# 49  \n\n\n  \n\nEnvironmental impact of the COVID-...
# 50  \n\n\n  \n\nHow Data Analytics and AI are used...
# 51  \n\n\n  \n\nAI Machine Learning Statistics and...
# 52  \n\n\n  \n\nPython became the choice for Data ...
# 53  \n\n\n  \n\nGoogle fit measure heart and respi...
# 54  \n\n\n  \n\nmobile apps - Future | blackcoffer...
# 55  \n\n\n  \n\nAI in health and medicine | impact...
# 56  \n\n\n  \n\ntelemedicine - What patients like ...
# 57  \n\n\n  \n\nforecast future technologies- how ...
# 58  \n\n\n  \n\nCan robots tackle life loneliness ...
# 59  \n\n\n  \n\nSocio-technical considerations - E...
# 60  \n\n\n  \n\nfuture digitalization of healthcar...
# 61  \n\n\n  \n\nAre we any closer to preventing a ...
# 62  \n\n\n  \n\nWill technology eliminate the need...
# 63  \n\n\n  \n\nWill we ever understand the nature...
# 64  \n\n\n  \n\nWill we ever colonize outer space?...
# 65  \n\n\n  \n\nWhat is the chance Homo sapiens wi...
# 66  \n\n\n  \n\nWhy does your business need a chat...
# 67  \n\n\n  \n\nHow you lead a project or a team w...
# 68  \n\n\n  \n\nCan You Be Great Leader Without Te...
# 69  \n\n\n  \n\nHow does artificial intelligence a...
# 70  \n\n\n  \n\nHow to Overcome Your Fear of Makin...
# 71  \n\n\n  \n\nIs Perfection the Greatest enemy o...
# 72  \n\n\n  \n\nGlobal financial crisis 2008 cause...
# 73  \n\n\n  \n\nGender diversity and Equality in t...
# 74  \n\n\n  \n\nHow to overcome your fear of makin...
# 75  \n\n\n  \n\nHow Small Business can survive the...
# 76  \n\n\n  \n\nImpacts of COVID 19 on Food produc...
# 77  \n\n\n  \n\nImpacts of COVID 19 on Vegetable V...
# 78  \n\n\n  \n\nImpact of COVID-19 pandemic on Tou...
# 79  \n\n\n  \n\nImpact of COVID-19 pandemic on spo...
# 80  \n\n\n  \n\nChanging landscape and emerging tr...
# 81  \n\n\n  \n\nOnline gaming: Adolescent online g...
# 82  \n\n\n  \n\nHuman Rights Outlook - Blackcoffer...
# 83  \n\n\n  \n\nHow Voice search makes your busine...
# 84  \n\n\n  \n\nHow the COVID-19 crisis is redefin...
# 85  \n\n\n  \n\nHow to increase social media engag...
# 86  \n\n\n  \n\nImpacts of COVID 19 on Streets Sid...
# 87  \n\n\n  \n\nCoronavirus impact on energy marke...
# 88  \n\n\n  \n\nCOVID-19 Impact on Hospitality Ind...
# 89  \n\n\n  \n\nkey learnings relevant to the coro...
# 90  \n\n\n  \n\nEstimating the impact of COVID-19 ...
# 91  \n\n\n  \n\nEstimating the impact of COVID-19 ...
# 92  \n\n\n  \n\nTravel and Tourism Outlook - Black...
# 93  \n\n\n  \n\nGaming Disorder and Effects of Gam...
# 94  \n\n\n  \n\nWhat is the repercussion of the en...
# 95  \n\n\n  \n\nDue to the COVID-19 the repercussi...
# 96  \n\n\n  \n\nImpact of COVID-19 pandemic on off...
# 97  \n\n\n  \n\nContribution of handicrafts (Visua...
# 98  \n\n\n  \n\nHow COVID-19 is impacting payment ...
# 99  \n\n\n  \n\nHow will COVID-19 affect the world...
#
#                                            clean_text  Positive_Score  \
# 0   [rising, cities, impact, economy, environment,...              61
# 1   [rising, cities, impact, economy, environment,...              83
# 2   [internet, demand, s, evolution, communication...              68
# 3   [rise, cybercrime, effect, upcoming, future, b...              68
# 4   [platform, impact, entertainment, industry, fu...              51
# 5   [rise, platform, impact, entertainment, indust...             119
# 6   [rise, cyber, crime, effects, blackcoffer, ins...              64
# 7   [rise, internet, demand, impact, communication...              62
# 8   [rise, cybercrime, effect, 2040, blackcoffer, ...              68
# 9   [rise, cybercrime, effect, 2040, blackcoffer, ...             160
# 10  [rise, internet, demand, impact, communication...              92
# 11  [rise, telemedicine, impact, livelihood, 2040,...             115
# 12  [rise, ehealth, impact, humans, 2030, blackcof...              73
# 13  [rise, ehealth, impact, humans, 2030, blackcof...              56
# 14  [rise, telemedicine, impact, livelihood, 2040,...              70
# 15  [rise, telemedicine, impact, livelihood, 2040,...              69
# 16  [rise, chatbots, impact, customer, support, 20...              90
# 17  [rise, ehealth, impact, humans, 2030, blackcof...              65
# 18  [marketing, influence, businesses, consumers, ...              91
# 19  [advertisement, increase, market, blackcoffer,...              40
# 20  [negative, effects, marketing, society, blackc...              53
# 21  [advertisementmarketing, affects, business, bl...              45
# 22  [rising, cities, impact, economy, environment,...              62
# 23  [rise, platform, impact, entertainment, indust...              54
# 24  [rise, electric, vehicles, impact, livelihood,...              48
# 25  [rise, electric, vehicle, impact, livelihood, ...              54
# 26  [oil, prices, 2040, impact, world, economy, bl...              55
# 27  [outlook, healthcare, 2040, impact, human, liv...              68
# 28  [healthcare, improve, patient, outcomes, black...             102
# 29  [creation, taking, creator, blackcoffer, insig...              92
# 30  [jobs, robots, humans, future, blackcoffer, in...              99
# 31  [machine, replace, human, future, work, blackc...             102
# 32  [replace, work, blackcoffer, insights, sign, s...              95
# 33  [machine, replace, human, future, work, blackc...              79
# 34  [humans, machines, evolving, work, blackcoffer...              59
# 35                                                 []               0
# 36  [machine, learning, affect, business, blackcof...              66
# 37  [deep, learning, impact, areas, elearning, bla...              96
# 38  [protect, future, data, privacy, blackcoffer, ...              87
# 39  [machines, automations, robohuman, effective, ...              67
# 40  [robo, human, impact, future, blackcoffer, ins...              61
# 41  [change, world, blackcoffer, insights, sign, s...              90
# 42  [future, work, entered, workplace, blackcoffer...             102
# 43  [machine, learning, finance, banking, blackcof...              58
# 44  [impact, future, work, blackcoffer, insights, ...             110
# 45  [online, marketing, blackcoffer, insights, sig...              58
# 46  [evolution, advertising, industry, blackcoffer...              48
# 47  [data, analytics, business, respond, impact, c...              38
# 48                                                 []               0
# 49  [environmental, impact, covid19, pandemic, les...              58
# 50  [data, analytics, halt, covid19, pandemic, bla...              49
# 51  [machine, learning, statistics, data, mining, ...              94
# 52  [python, choice, data, science, s, sign, succe...              77
# 53  [google, fit, measure, heart, respiratory, rat...              37
# 54  [mobile, apps, future, blackcoffer, insights, ...              59
# 55  [health, medicine, impact, blackcoffer, insigh...              61
# 56  [telemedicine, patients, dislike, blackcoffer,...              49
# 57  [forecast, future, technologies, blackcoffer, ...              38
# 58  [robots, tackle, life, loneliness, blackcoffer...              55
# 59  [sociotechnical, considerations, embedding, ca...              40
# 60  [future, digitalization, healthcare, services,...              81
# 61  [closer, preventing, nuclear, holocaust, black...              43
# 62  [technology, eliminate, animal, testing, drug,...              57
# 63  [understand, nature, consciousness, blackcoffe...              60
# 64  [colonize, outer, space, blackcoffer, insights...              78
# 65  [homo, sapiens, survive, 500, years, blackcoff...              63
# 66  [business, chatbot, blackcoffer, insights, sig...              59
# 67  [lead, project, team, technical, expertise, bl...              78
# 68  [great, leader, technical, expertise, blackcof...              64
# 69  [artificial, intelligence, affect, environment...              72
# 70  [overcome, fear, making, mistakes, blackcoffer...              58
# 71  [perfection, greatest, enemy, productivity, bl...             100
# 72  [global, financial, crisis, 2008, causeseffect...              60
# 73  [gender, diversity, equality, tech, industry, ...              62
# 74  [overcome, fear, making, mistakes, blackcoffer...              56
# 75  [business, survive, coronavirus, crisis, black...              71
# 76  [impacts, covid, 19, food, products, blackcoff...              55
# 77  [impacts, covid, 19, vegetable, vendors, black...              67
# 78  [impact, covid19, pandemic, tourism, aviation,...              64
# 79  [impact, covid19, pandemic, sports, events, wo...              66
# 80  [changing, landscape, emerging, trends, itites...              68
# 81  [online, gaming, adolescent, online, gaming, e...              61
# 82  [human, rights, outlook, blackcoffer, insights...              37
# 83  [voice, search, makes, business, successful, b...              64
# 84  [covid19, crisis, redefining, jobs, services, ...              72
# 85  [increase, social, media, engagement, marketer...              86
# 86  [impacts, covid, 19, streets, food, stalls, bl...              62
# 87  [coronavirus, impact, energy, markets, blackco...              52
# 88  [covid19, impact, hospitality, industrty, blac...              50
# 89  [learnings, relevant, coronavirus, crisis, les...              67
# 90  [estimating, impact, covid19, world, work, bla...              57
# 91  [estimating, impact, covid19, world, work, bla...              61
# 92  [travel, tourism, outlook, blackcoffer, insigh...              34
# 93  [gaming, disorder, effects, gaming, health, bl...              65
# 94  [repercussion, environment, due, covid19, pand...              41
# 95  [due, covid19, repercussion, environment, blac...              58
# 96  [impact, covid19, pandemic, office, space, cow...              55
# 97  [contribution, handicrafts, visual, arts, lite...              41
# 98  [covid19, impacting, payment, preferences, bla...              49
# 99  [covid19, affect, world, work, blackcoffer, in...              72
#
#     Negative_score  Polarity_Score  Subjectivity_Score
# 0               10        0.718310            0.064195
# 1               34        0.418803            0.089381
# 2               26        0.446809            0.077049
# 3               80       -0.081081            0.123128
# 4               12        0.619048            0.067236
# 5               30        0.597315            0.090965
# 6               73       -0.065693            0.108044
# 7               13        0.653333            0.068807
# 8               56        0.096774            0.104377
# 9              184       -0.069767            0.150350
# 10              23        0.600000            0.082437
# 11              27        0.619718            0.097931
# 12              18        0.604396            0.102132
# 13              30        0.302326            0.074394
# 14              30        0.400000            0.080906
# 15              30        0.393939            0.080097
# 16              14        0.730769            0.088285
# 17              13        0.666667            0.067650
# 18               9        0.820000            0.070721
# 19               3        0.860465            0.051621
# 20              52        0.009524            0.094595
# 21              15        0.500000            0.077720
# 22              19        0.530864            0.068297
# 23               6        0.800000            0.067797
# 24              13        0.573770            0.058317
# 25              18        0.500000            0.067733
# 26              29        0.309524            0.072853
# 27              29        0.402062            0.084495
# 28              35        0.489051            0.085840
# 29              40        0.393939            0.114385
# 30              39        0.434783            0.096167
# 31              33        0.511111            0.107741
# 32              29        0.532258            0.089920
# 33              26        0.504762            0.090595
# 34              14        0.616438            0.077825
# 35               0        0.000000            0.000000
# 36              16        0.609756            0.088267
# 37              36        0.454545            0.086899
# 38              60        0.183673            0.094839
# 39              28        0.410526            0.080304
# 40              35        0.270833            0.080944
# 41              27        0.538462            0.092857
# 42              24        0.619048            0.092852
# 43               4        0.870968            0.073286
# 44              43        0.437908            0.119438
# 45               6        0.812500            0.061598
# 46               9        0.684211            0.060127
# 47               7        0.688889            0.060080
# 48               0        0.000000            0.000000
# 49              73       -0.114504            0.104466
# 50              17        0.484848            0.071506
# 51              41        0.392593            0.098684
# 52               6        0.855422            0.089151
# 53               3        0.850000            0.049875
# 54              13        0.638889            0.062827
# 55              12        0.671233            0.078834
# 56              14        0.555556            0.083113
# 57               5        0.767442            0.062229
# 58              42        0.134021            0.103854
# 59               8        0.666667            0.070073
# 60              23        0.557692            0.084691
# 61              24        0.283582            0.079667
# 62              41        0.163265            0.093960
# 63              52        0.071429            0.080518
# 64              26        0.500000            0.080808
# 65              28        0.384615            0.075456
# 66              12        0.661972            0.078889
# 67              12        0.733333            0.083955
# 68              10        0.729730            0.098013
# 69              19        0.582418            0.070597
# 70              80       -0.159420            0.140816
# 71              30        0.538462            0.122757
# 72              49        0.100917            0.093804
# 73              31        0.333333            0.071374
# 74              87       -0.216783            0.143000
# 75              40        0.279279            0.089951
# 76              16        0.549296            0.073651
# 77              27        0.425532            0.079325
# 78              51        0.113043            0.084311
# 79              18        0.571429            0.037567
# 80              45        0.203540            0.083149
# 81              75       -0.102941            0.096181
# 82               6        0.720930            0.061960
# 83               8        0.777778            0.067606
# 84              36        0.333333            0.084639
# 85              23        0.577982            0.079388
# 86              38        0.240000            0.091827
# 87              44        0.083333            0.065262
# 88              45        0.052632            0.091522
# 89              54        0.107438            0.110301
# 90              31        0.295455            0.083650
# 91              47        0.129630            0.083981
# 92               7        0.658537            0.061469
# 93              52        0.111111            0.105405
# 94              28        0.188406            0.075575
# 95              57        0.008696            0.100000
# 96              38        0.182796            0.091445
# 97               6        0.744681            0.057882
# 98               6        0.781818            0.060706
# 99              62        0.074627            0.116725

# %% [markdown]
# # Analysis of Readability

# %%
def count_words(sentence):
    if type(sentence) == str:
        words = re.findall(r'\b\w+\b', sentence)  # Extract words using regex
    elif type(sentence) == list:
        words = []
        for word in sentence:
            words.extend(re.findall(r'\b\w+\b', word))
    return len(words)

def count_sentences(content):
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|\!)\s', content)
    return len(sentences)

# %%
def count_complex_words(words):
    # Consider words with length > 2 as complex words
    complex_words = [word for word in words if len(word) > 2]  
    return len(complex_words)

#Fog Index = 0.4 * (Average Sentence Length + Percentage of Complex words)

def fog_index(avg_sentence_length, percentage_complex_words):
    return 0.4 * (avg_sentence_length + percentage_complex_words)

# %%
def count_syllables(word):
    # Remove trailing 'es' or 'ed' to handle exceptions
    word = re.sub(r'(es|ed)$', '', word)
    
    # Count the number of vowels
    vowels = re.findall(r'[aeiou]+', word)
    
    # Adjust the count for words with a single vowel at the end, not counting 'e' unless it's the only vowel
    if len(vowels) > 1 and vowels[-1] == 'e':
        vowels.pop()  # Remove the last 'e' if it's not the only vowel
    
    return len(vowels)

# %%
def count_personal_pronouns(text):
    pattern = r'\b(I|we|my|ours|us)\b'
    matches = re.findall(pattern, text)
    return len(matches)

# %%
def average_word_length(text):
    # Tokenize the text into words
    words = re.findall(r'\b\w+\b', text)
    # Calculate the total number of characters in all words
    total_characters = sum(len(word) for word in words)
    # Calculate the total number of words
    total_words = len(words)
    # Calculate the average word length
    if total_words != 0:
        return total_characters / total_words
    else:
        return 0  # Handle case where there are no words

# %%
content['Average_Sentence_Length'] = content['content'].apply(lambda x: count_words(x) / count_sentences(x))

# %%
content['Percentage_of_Complex_Words'] = content['clean_text'].apply(lambda x: 0 if count_complex_words(x) == 0 else 100*(count_complex_words(x) / len(x)))

# %%
content['Fog_Index'] = fog_index(content['Average_Sentence_Length'], content['Percentage_of_Complex_Words'])

# %%
content['Average_Number_of_Words_Per_Sentence'] = content.apply(lambda x : len(x['clean_text']) / count_sentences(x['content']),axis= 1)

# %%
content['Complex_Word_Count'] = content['clean_text'].apply(lambda x:(count_complex_words(x)))

# %%
content['Word_Count'] = content['clean_text'].apply(lambda x : len(x))

# %%
content['Average_Syllable_Count_Per_Word'] = content['clean_text'].apply(lambda x: np.mean([count_syllables(i) for i in x]))

# %%
content['Personal_Pronouns_Count'] = content['content'].apply(count_personal_pronouns)

# %%
content['Average_Word_Length'] = content['content'].apply(average_word_length)

# %%
content
# Out:
#                                               content  \
# 0   \n\n\n  \n\nRising IT cities and its impact on...
# 1   \n\n\n  \n\nRising IT Cities and Their Impact ...
# 2   \n\n\n  \n\nInternet Demand's Evolution, Commu...
# 3   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 4   \n\n\n  \n\nOTT platform and its impact on the...
# 5   \n\n\n  \n\nThe rise of the OTT platform and i...
# 6   \n\n\n  \n\nRise of Cyber Crime and its Effect...
# 7   \n\n\n  \n\nRise of Internet Demand and Its Im...
# 8   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 9   \n\n\n  \n\nRise of Cybercrime and its Effect ...
# 10  \n\n\n  \n\nRise of Internet Demand and its Im...
# 11  \n\n\n  \n\nRise of telemedicine and its Impac...
# 12  \n\n\n  \n\nRise of e-health and its impact on...
# 13  \n\n\n  \n\nRise of e-health and its impact on...
# 14  \n\n\n  \n\nRise of telemedicine and its Impac...
# 15  \n\n\n  \n\nRise of telemedicine and its Impac...
# 16  \n\n\n  \n\nRise of Chatbots and its impact on...
# 17  \n\n\n  \n\nRise of e-health and its impact on...
# 18  \n\n\n  \n\nHow does marketing influence busin...
# 19  \n\n\n  \n\nHow advertisement increase your ma...
# 20  \n\n\n  \n\nNegative effects of marketing on s...
# 21  \n\n\n  \n\nHow advertisement/marketing affect...
# 22  \n\n\n  \n\nRising IT cities will impact the e...
# 23  \n\n\n  \n\nRise of OTT platform and its impac...
# 24  \n\n\n  \n\nRise of Electric Vehicles and its ...
# 25  \n\n\n  \n\nRise of electric vehicle and its i...
# 26  \n\n\n  \n\nOil prices by the year 2040, and h...
# 27  \n\n\n  \n\nAn outlook of healthcare by the ye...
# 28  \n\n\n  \n\nAI in healthcare to Improve Patien...
# 29  \n\n\n  \n\nWhat if the Creation is Taking Ove...
# 30  \n\n\n  \n\nWhat Jobs Will Robots Take From Hu...
# 31  \n\n\n  \n\nWill Machine Replace The Human in ...
# 32  \n\n\n  \n\nWill AI Replace Us or Work With Us...
# 33  \n\n\n  \n\nWill machine replace the human in ...
# 34  \n\n\n  \n\nHow humans and machines are evolvi...
# 35                                               None
# 36  \n\n\n  \n\nHow machine learning will affect y...
# 37  \n\n\n  \n\nDeep learning impact on areas of e...
# 38  \n\n\n  \n\nHow to protect future data and its...
# 39  \n\n\n  \n\nHow Machines, AI, Automations, and...
# 40  \n\n\n  \n\nHow Robo Human will Impact the Fut...
# 41  \n\n\n  \n\nHow AI will change the World? - Bl...
# 42  \n\n\n  \n\nFuture of Work: How AI Has Entered...
# 43  \n\n\n  \n\nHow machine learning used in finan...
# 44  \n\n\n  \n\nHow AI will impact the future of w...
# 45  \n\n\n  \n\nAll you need to know about online ...
# 46  \n\n\n  \n\nEvolution of Advertising Industry ...
# 47  \n\n\n  \n\nHow Data Analytics can help your b...
# 48                                               None
# 49  \n\n\n  \n\nEnvironmental impact of the COVID-...
# 50  \n\n\n  \n\nHow Data Analytics and AI are used...
# 51  \n\n\n  \n\nAI Machine Learning Statistics and...
# 52  \n\n\n  \n\nPython became the choice for Data ...
# 53  \n\n\n  \n\nGoogle fit measure heart and respi...
# 54  \n\n\n  \n\nmobile apps - Future | blackcoffer...
# 55  \n\n\n  \n\nAI in health and medicine | impact...
# 56  \n\n\n  \n\ntelemedicine - What patients like ...
# 57  \n\n\n  \n\nforecast future technologies- how ...
# 58  \n\n\n  \n\nCan robots tackle life loneliness ...
# 59  \n\n\n  \n\nSocio-technical considerations - E...
# 60  \n\n\n  \n\nfuture digitalization of healthcar...
# 61  \n\n\n  \n\nAre we any closer to preventing a ...
# 62  \n\n\n  \n\nWill technology eliminate the need...
# 63  \n\n\n  \n\nWill we ever understand the nature...
# 64  \n\n\n  \n\nWill we ever colonize outer space?...
# 65  \n\n\n  \n\nWhat is the chance Homo sapiens wi...
# 66  \n\n\n  \n\nWhy does your business need a chat...
# 67  \n\n\n  \n\nHow you lead a project or a team w...
# 68  \n\n\n  \n\nCan You Be Great Leader Without Te...
# 69  \n\n\n  \n\nHow does artificial intelligence a...
# 70  \n\n\n  \n\nHow to Overcome Your Fear of Makin...
# 71  \n\n\n  \n\nIs Perfection the Greatest enemy o...
# 72  \n\n\n  \n\nGlobal financial crisis 2008 cause...
# 73  \n\n\n  \n\nGender diversity and Equality in t...
# 74  \n\n\n  \n\nHow to overcome your fear of makin...
# 75  \n\n\n  \n\nHow Small Business can survive the...
# 76  \n\n\n  \n\nImpacts of COVID 19 on Food produc...
# 77  \n\n\n  \n\nImpacts of COVID 19 on Vegetable V...
# 78  \n\n\n  \n\nImpact of COVID-19 pandemic on Tou...
# 79  \n\n\n  \n\nImpact of COVID-19 pandemic on spo...
# 80  \n\n\n  \n\nChanging landscape and emerging tr...
# 81  \n\n\n  \n\nOnline gaming: Adolescent online g...
# 82  \n\n\n  \n\nHuman Rights Outlook - Blackcoffer...
# 83  \n\n\n  \n\nHow Voice search makes your busine...
# 84  \n\n\n  \n\nHow the COVID-19 crisis is redefin...
# 85  \n\n\n  \n\nHow to increase social media engag...
# 86  \n\n\n  \n\nImpacts of COVID 19 on Streets Sid...
# 87  \n\n\n  \n\nCoronavirus impact on energy marke...
# 88  \n\n\n  \n\nCOVID-19 Impact on Hospitality Ind...
# 89  \n\n\n  \n\nkey learnings relevant to the coro...
# 90  \n\n\n  \n\nEstimating the impact of COVID-19 ...
# 91  \n\n\n  \n\nEstimating the impact of COVID-19 ...
# 92  \n\n\n  \n\nTravel and Tourism Outlook - Black...
# 93  \n\n\n  \n\nGaming Disorder and Effects of Gam...
# 94  \n\n\n  \n\nWhat is the repercussion of the en...
# 95  \n\n\n  \n\nDue to the COVID-19 the repercussi...
# 96  \n\n\n  \n\nImpact of COVID-19 pandemic on off...
# 97  \n\n\n  \n\nContribution of handicrafts (Visua...
# 98  \n\n\n  \n\nHow COVID-19 is impacting payment ...
# 99  \n\n\n  \n\nHow will COVID-19 affect the world...
#
#                                            clean_text  Positive_Score  \
# 0   [rising, cities, impact, economy, environment,...              61
# 1   [rising, cities, impact, economy, environment,...              83
# 2   [internet, demand, s, evolution, communication...              68
# 3   [rise, cybercrime, effect, upcoming, future, b...              68
# 4   [platform, impact, entertainment, industry, fu...              51
# 5   [rise, platform, impact, entertainment, indust...             119
# 6   [rise, cyber, crime, effects, blackcoffer, ins...              64
# 7   [rise, internet, demand, impact, communication...              62
# 8   [rise, cybercrime, effect, 2040, blackcoffer, ...              68
# 9   [rise, cybercrime, effect, 2040, blackcoffer, ...             160
# 10  [rise, internet, demand, impact, communication...              92
# 11  [rise, telemedicine, impact, livelihood, 2040,...             115
# 12  [rise, ehealth, impact, humans, 2030, blackcof...              73
# 13  [rise, ehealth, impact, humans, 2030, blackcof...              56
# 14  [rise, telemedicine, impact, livelihood, 2040,...              70
# 15  [rise, telemedicine, impact, livelihood, 2040,...              69
# 16  [rise, chatbots, impact, customer, support, 20...              90
# 17  [rise, ehealth, impact, humans, 2030, blackcof...              65
# 18  [marketing, influence, businesses, consumers, ...              91
# 19  [advertisement, increase, market, blackcoffer,...              40
# 20  [negative, effects, marketing, society, blackc...              53
# 21  [advertisementmarketing, affects, business, bl...              45
# 22  [rising, cities, impact, economy, environment,...              62
# 23  [rise, platform, impact, entertainment, indust...              54
# 24  [rise, electric, vehicles, impact, livelihood,...              48
# 25  [rise, electric, vehicle, impact, livelihood, ...              54
# 26  [oil, prices, 2040, impact, world, economy, bl...              55
# 27  [outlook, healthcare, 2040, impact, human, liv...              68
# 28  [healthcare, improve, patient, outcomes, black...             102
# 29  [creation, taking, creator, blackcoffer, insig...              92
# 30  [jobs, robots, humans, future, blackcoffer, in...              99
# 31  [machine, replace, human, future, work, blackc...             102
# 32  [replace, work, blackcoffer, insights, sign, s...              95
# 33  [machine, replace, human, future, work, blackc...              79
# 34  [humans, machines, evolving, work, blackcoffer...              59
# 35                                                 []               0
# 36  [machine, learning, affect, business, blackcof...              66
# 37  [deep, learning, impact, areas, elearning, bla...              96
# 38  [protect, future, data, privacy, blackcoffer, ...              87
# 39  [machines, automations, robohuman, effective, ...              67
# 40  [robo, human, impact, future, blackcoffer, ins...              61
# 41  [change, world, blackcoffer, insights, sign, s...              90
# 42  [future, work, entered, workplace, blackcoffer...             102
# 43  [machine, learning, finance, banking, blackcof...              58
# 44  [impact, future, work, blackcoffer, insights, ...             110
# 45  [online, marketing, blackcoffer, insights, sig...              58
# 46  [evolution, advertising, industry, blackcoffer...              48
# 47  [data, analytics, business, respond, impact, c...              38
# 48                                                 []               0
# 49  [environmental, impact, covid19, pandemic, les...              58
# 50  [data, analytics, halt, covid19, pandemic, bla...              49
# 51  [machine, learning, statistics, data, mining, ...              94
# 52  [python, choice, data, science, s, sign, succe...              77
# 53  [google, fit, measure, heart, respiratory, rat...              37
# 54  [mobile, apps, future, blackcoffer, insights, ...              59
# 55  [health, medicine, impact, blackcoffer, insigh...              61
# 56  [telemedicine, patients, dislike, blackcoffer,...              49
# 57  [forecast, future, technologies, blackcoffer, ...              38
# 58  [robots, tackle, life, loneliness, blackcoffer...              55
# 59  [sociotechnical, considerations, embedding, ca...              40
# 60  [future, digitalization, healthcare, services,...              81
# 61  [closer, preventing, nuclear, holocaust, black...              43
# 62  [technology, eliminate, animal, testing, drug,...              57
# 63  [understand, nature, consciousness, blackcoffe...              60
# 64  [colonize, outer, space, blackcoffer, insights...              78
# 65  [homo, sapiens, survive, 500, years, blackcoff...              63
# 66  [business, chatbot, blackcoffer, insights, sig...              59
# 67  [lead, project, team, technical, expertise, bl...              78
# 68  [great, leader, technical, expertise, blackcof...              64
# 69  [artificial, intelligence, affect, environment...              72
# 70  [overcome, fear, making, mistakes, blackcoffer...              58
# 71  [perfection, greatest, enemy, productivity, bl...             100
# 72  [global, financial, crisis, 2008, causeseffect...              60
# 73  [gender, diversity, equality, tech, industry, ...              62
# 74  [overcome, fear, making, mistakes, blackcoffer...              56
# 75  [business, survive, coronavirus, crisis, black...              71
# 76  [impacts, covid, 19, food, products, blackcoff...              55
# 77  [impacts, covid, 19, vegetable, vendors, black...              67
# 78  [impact, covid19, pandemic, tourism, aviation,...              64
# 79  [impact, covid19, pandemic, sports, events, wo...              66
# 80  [changing, landscape, emerging, trends, itites...              68
# 81  [online, gaming, adolescent, online, gaming, e...              61
# 82  [human, rights, outlook, blackcoffer, insights...              37
# 83  [voice, search, makes, business, successful, b...              64
# 84  [covid19, crisis, redefining, jobs, services, ...              72
# 85  [increase, social, media, engagement, marketer...              86
# 86  [impacts, covid, 19, streets, food, stalls, bl...              62
# 87  [coronavirus, impact, energy, markets, blackco...              52
# 88  [covid19, impact, hospitality, industrty, blac...              50
# 89  [learnings, relevant, coronavirus, crisis, les...              67
# 90  [estimating, impact, covid19, world, work, bla...              57
# 91  [estimating, impact, covid19, world, work, bla...              61
# 92  [travel, tourism, outlook, blackcoffer, insigh...              34
# 93  [gaming, disorder, effects, gaming, health, bl...              65
# 94  [repercussion, environment, due, covid19, pand...              41
# 95  [due, covid19, repercussion, environment, blac...              58
# 96  [impact, covid19, pandemic, office, space, cow...              55
# 97  [contribution, handicrafts, visual, arts, lite...              41
# 98  [covid19, impacting, payment, preferences, bla...              49
# 99  [covid19, affect, world, work, blackcoffer, in...              72
#
#     Negative_score  Polarity_Score  Subjectivity_Score  \
# 0               10        0.718310            0.064195
# 1               34        0.418803            0.089381
# 2               26        0.446809            0.077049
# 3               80       -0.081081            0.123128
# 4               12        0.619048            0.067236
# 5               30        0.597315            0.090965
# 6               73       -0.065693            0.108044
# 7               13        0.653333            0.068807
# 8               56        0.096774            0.104377
# 9              184       -0.069767            0.150350
# 10              23        0.600000            0.082437
# 11              27        0.619718            0.097931
# 12              18        0.604396            0.102132
# 13              30        0.302326            0.074394
# 14              30        0.400000            0.080906
# 15              30        0.393939            0.080097
# 16              14        0.730769            0.088285
# 17              13        0.666667            0.067650
# 18               9        0.820000            0.070721
# 19               3        0.860465            0.051621
# 20              52        0.009524            0.094595
# 21              15        0.500000            0.077720
# 22              19        0.530864            0.068297
# 23               6        0.800000            0.067797
# 24              13        0.573770            0.058317
# 25              18        0.500000            0.067733
# 26              29        0.309524            0.072853
# 27              29        0.402062            0.084495
# 28              35        0.489051            0.085840
# 29              40        0.393939            0.114385
# 30              39        0.434783            0.096167
# 31              33        0.511111            0.107741
# 32              29        0.532258            0.089920
# 33              26        0.504762            0.090595
# 34              14        0.616438            0.077825
# 35               0        0.000000            0.000000
# 36              16        0.609756            0.088267
# 37              36        0.454545            0.086899
# 38              60        0.183673            0.094839
# 39              28        0.410526            0.080304
# 40              35        0.270833            0.080944
# 41              27        0.538462            0.092857
# 42              24        0.619048            0.092852
# 43               4        0.870968            0.073286
# 44              43        0.437908            0.119438
# 45               6        0.812500            0.061598
# 46               9        0.684211            0.060127
# 47               7        0.688889            0.060080
# 48               0        0.000000            0.000000
# 49              73       -0.114504            0.104466
# 50              17        0.484848            0.071506
# 51              41        0.392593            0.098684
# 52               6        0.855422            0.089151
# 53               3        0.850000            0.049875
# 54              13        0.638889            0.062827
# 55              12        0.671233            0.078834
# 56              14        0.555556            0.083113
# 57               5        0.767442            0.062229
# 58              42        0.134021            0.103854
# 59               8        0.666667            0.070073
# 60              23        0.557692            0.084691
# 61              24        0.283582            0.079667
# 62              41        0.163265            0.093960
# 63              52        0.071429            0.080518
# 64              26        0.500000            0.080808
# 65              28        0.384615            0.075456
# 66              12        0.661972            0.078889
# 67              12        0.733333            0.083955
# 68              10        0.729730            0.098013
# 69              19        0.582418            0.070597
# 70              80       -0.159420            0.140816
# 71              30        0.538462            0.122757
# 72              49        0.100917            0.093804
# 73              31        0.333333            0.071374
# 74              87       -0.216783            0.143000
# 75              40        0.279279            0.089951
# 76              16        0.549296            0.073651
# 77              27        0.425532            0.079325
# 78              51        0.113043            0.084311
# 79              18        0.571429            0.037567
# 80              45        0.203540            0.083149
# 81              75       -0.102941            0.096181
# 82               6        0.720930            0.061960
# 83               8        0.777778            0.067606
# 84              36        0.333333            0.084639
# 85              23        0.577982            0.079388
# 86              38        0.240000            0.091827
# 87              44        0.083333            0.065262
# 88              45        0.052632            0.091522
# 89              54        0.107438            0.110301
# 90              31        0.295455            0.083650
# 91              47        0.129630            0.083981
# 92               7        0.658537            0.061469
# 93              52        0.111111            0.105405
# 94              28        0.188406            0.075575
# 95              57        0.008696            0.100000
# 96              38        0.182796            0.091445
# 97               6        0.744681            0.057882
# 98               6        0.781818            0.060706
# 99              62        0.074627            0.116725
#
#     Average_Sentence_Length  Percentage_of_Complex_Words  Fog_Index  \
# 0                 23.615385                    96.925859  48.216497
# 1                 25.195876                    97.249809  48.978274
# 2                 28.714286                    97.295082  50.403747
# 3                 31.476190                    97.587354  51.625418
# 4                 29.833333                    96.905016  50.695340
# 5                 26.742857                    97.130647  49.549402
# 6                 25.375000                    96.687697  48.825079
# 7                 28.600000                    95.412844  49.605138
# 8                 25.635135                    96.885522  49.008263
# 9                 18.395257                    98.470280  46.746215
# 10                28.686747                    97.347670  50.413767
# 11                28.777778                    97.862069  50.655939
# 12                43.027778                    96.745230  55.909203
# 13                26.883117                    96.453287  49.334562
# 14                30.250000                    96.925566  50.870227
# 15                31.420290                    96.844660  51.305980
# 16                27.090909                    96.859083  49.579997
# 17                36.410714                    96.617520  53.211294
# 18                24.263636                    97.312588  48.630490
# 19                38.025641                    95.798319  53.529584
# 20                31.193548                    97.027027  51.288230
# 21                31.116279                    95.984456  50.840294
# 22                30.051948                    96.964587  50.806614
# 23                47.218750                    95.819209  57.215184
# 24                56.742857                    95.315488  60.823338
# 25                33.142857                    95.202258  51.338046
# 26                33.478261                    95.576756  51.622007
# 27                38.592593                    96.341463  53.973622
# 28                31.908046                    97.117794  51.610336
# 29                25.000000                    96.620451  48.648180
# 30                25.990196                    97.560976  49.420469
# 31                23.387387                    97.126895  48.205713
# 32                29.096774                    97.099347  50.478449
# 33                28.025000                    96.980155  50.002062
# 34                27.245902                    95.842217  49.235248
# 35                 1.000000                     0.000000   0.400000
# 36                32.705882                    96.124865  51.532299
# 37                31.555556                    97.498354  51.621564
# 38                24.725000                    97.612903  48.935161
# 39                29.830986                    97.379544  50.884212
# 40                22.645833                    96.711636  47.742988
# 41                38.507246                    96.587302  54.037819
# 42                28.279570                    96.315402  49.837989
# 43                39.666667                    96.453901  54.448227
# 44               105.115385                    96.643247  80.703453
# 45                27.352941                    97.016362  49.747721
# 46                30.865385                    96.518987  50.953749
# 47                49.680000                    95.861148  58.216459
# 48                 1.000000                     0.000000   0.400000
# 49                33.579710                    97.288676  52.347355
# 50                40.487805                    95.991333  54.591655
# 51                22.753968                    97.368421  48.048956
# 52                28.428571                    96.240602  49.867669
# 53                40.906250                    96.259352  54.866241
# 54                31.454545                    96.073298  51.011138
# 55                43.485714                    96.328294  55.925603
# 56                30.000000                    95.646438  50.258575
# 57                45.782609                    95.803184  56.634317
# 58                24.700000                    96.895075  48.638030
# 59                45.041667                    95.474453  56.206448
# 60                30.579710                    96.498371  50.831233
# 61                43.696970                    96.195006  55.956790
# 62                29.924242                    96.644295  50.627415
# 63                29.651685                    97.627606  50.911717
# 64                32.390244                    97.047397  51.775056
# 65                24.204082                    96.766169  48.388100
# 66                23.142857                    95.444444  47.434921
# 67                30.220779                    97.014925  50.894282
# 68                48.678571                    96.158940  57.935005
# 69                30.132530                    97.284717  50.966899
# 70                22.068966                    96.938776  47.603096
# 71                22.148936                    96.883853  47.613116
# 72                40.230769                    96.815835  54.818642
# 73                27.252874                    95.395242  49.059246
# 74                21.413043                    96.800000  47.285217
# 75                37.119403                    96.758509  53.551165
# 76                48.485714                    96.473029  57.983497
# 77                42.540000                    96.877637  55.767055
# 78                31.345238                    96.920821  51.306424
# 79                17.550201                    93.425760  44.390384
# 80                27.670103                    96.688742  49.743538
# 81                34.112676                    97.312588  52.570106
# 82                58.210526                    95.100865  61.324556
# 83                33.482759                    94.460094  51.177141
# 84                20.578947                    97.570533  47.259792
# 85                25.129630                    97.450838  49.032187
# 86                34.534483                    96.510560  52.418017
# 87                38.771429                    95.853161  53.849836
# 88                31.216667                    96.146435  50.945241
# 89                25.154762                    97.356427  49.004475
# 90                42.893617                    96.768061  55.864671
# 91                38.810345                    95.256610  53.626782
# 92                47.956522                    95.052474  57.203598
# 93                25.280488                    97.027027  48.923006
# 94                31.775510                    95.618839  50.957740
# 95                33.803279                    96.956522  52.303920
# 96                39.294118                    96.361849  54.262386
# 97                64.800000                    95.812808  64.245123
# 98                37.804878                    94.591611  52.958596
# 99                46.790698                    96.428571  57.287708
#
#     Average_Number_of_Words_Per_Sentence  Complex_Word_Count  Word_Count  \
# 0                              12.153846                1072        1106
# 1                              13.494845                1273        1309
# 2                              17.428571                1187        1220
# 3                              19.079365                1173        1202
# 4                              17.351852                 908         937
# 5                              15.600000                1591        1638
# 6                              14.409091                1226        1268
# 7                              18.166667                1040        1090
# 8                              16.054054                1151        1188
# 9                               9.043478                2253        2288
# 10                             16.807229                1358        1395
# 11                             16.111111                1419        1450
# 12                             24.750000                 862         891
# 13                             15.012987                1115        1156
# 14                             17.166667                1198        1236
# 15                             17.913043                1197        1236
# 16                             15.298701                1141        1178
# 17                             20.589286                1114        1153
# 18                             12.854545                1376        1414
# 19                             21.358974                 798         833
# 20                             17.903226                1077        1110
# 21                             17.953488                 741         772
# 22                             15.402597                1150        1186
# 23                             27.656250                 848         885
# 24                             29.885714                 997        1046
# 25                             18.982143                1012        1063
# 26                             16.710145                1102        1153
# 27                             21.259259                1106        1148
# 28                             18.344828                1550        1596
# 29                             12.276596                1115        1154
# 30                             14.068627                1400        1435
# 31                             11.288288                1217        1253
# 32                             14.827957                1339        1379
# 33                             14.487500                1124        1159
# 34                             15.377049                 899         938
# 35                              0.000000                   0           0
# 36                             18.215686                 893         929
# 37                             15.343434                1481        1519
# 38                             12.916667                1513        1550
# 39                             16.661972                1152        1183
# 40                             12.354167                1147        1186
# 41                             18.260870                1217        1260
# 42                             14.591398                1307        1357
# 43                             23.500000                 816         846
# 44                             49.269231                1238        1281
# 45                             15.279412                1008        1039
# 46                             18.230769                 915         948
# 47                             29.960000                 718         749
# 48                              0.000000                   0           0
# 49                             18.173913                1220        1254
# 50                             22.512195                 886         923
# 51                             10.857143                1332        1368
# 52                             16.625000                 896         931
# 53                             25.062500                 772         802
# 54                             17.363636                1101        1146
# 55                             26.457143                 892         926
# 56                             17.627907                 725         758
# 57                             30.043478                 662         691
# 58                             13.342857                 905         934
# 59                             28.541667                 654         685
# 60                             17.797101                1185        1228
# 61                             25.484848                 809         841
# 62                             15.803030                1008        1043
# 63                             15.629213                1358        1391
# 64                             15.695122                1249        1287
# 65                             12.306122                1167        1206
# 66                             11.688312                 859         900
# 67                             13.922078                1040        1072
# 68                             26.964286                 726         755
# 69                             15.530120                1254        1289
# 70                             11.264368                 950         980
# 71                             11.265957                1026        1059
# 72                             22.346154                1125        1162
# 73                             14.977011                1243        1303
# 74                             10.869565                 968        1000
# 75                             18.417910                1194        1234
# 76                             27.542857                 930         964
# 77                             23.700000                1148        1185
# 78                             16.238095                1322        1364
# 79                              8.979920                2089        2236
# 80                             14.010309                1314        1359
# 81                             19.915493                1376        1414
# 82                             36.526316                 660         694
# 83                             18.362069                1006        1065
# 84                              9.593985                1245        1276
# 85                             12.712963                1338        1373
# 86                             18.775862                1051        1089
# 87                             21.014286                1410        1471
# 88                             17.300000                 998        1038
# 89                             13.059524                1068        1097
# 90                             22.382979                1018        1052
# 91                             22.172414                1225        1286
# 92                             29.000000                 634         667
# 93                             13.536585                1077        1110
# 94                             18.632653                 873         913
# 95                             18.852459                1115        1150
# 96                             19.941176                 980        1017
# 97                             40.600000                 778         812
# 98                             22.097561                 857         906
# 99                             26.697674                1107        1148
#
#     Average_Syllable_Count_Per_Word  Personal_Pronouns_Count  \
# 0                          2.120253                        7
# 1                          2.266616                        4
# 2                          2.380328                       15
# 3                          2.306988                        5
# 4                          2.228388                        8
# 5                          2.282051                        7
# 6                          2.165615                        2
# 7                          2.369725                        4
# 8                          2.351010                        4
# 9                          2.277098                       14
# 10                         2.315412                        3
# 11                         2.322759                        3
# 12                         2.300786                        4
# 13                         2.202422                        4
# 14                         2.165858                        8
# 15                         2.169903                        7
# 16                         2.220713                        6
# 17                         2.235906                        2
# 18                         2.219236                        5
# 19                         2.264106                        2
# 20                         2.292793                        8
# 21                         2.266839                        5
# 22                         2.197302                        9
# 23                         2.220339                        2
# 24                         2.083174                        5
# 25                         2.149577                        3
# 26                         2.044232                       20
# 27                         2.185540                        8
# 28                         2.246867                        2
# 29                         2.171577                        7
# 30                         2.278746                        3
# 31                         2.167598                       18
# 32                         2.172589                       13
# 33                         2.172563                       19
# 34                         2.224947                        8
# 35                              NaN                        0
# 36                         2.133477                        3
# 37                         2.173799                       10
# 38                         2.078710                        3
# 39                         2.309383                        9
# 40                         2.163575                        7
# 41                         2.261905                       34
# 42                         2.155490                       12
# 43                         2.275414                        1
# 44                         2.126464                       17
# 45                         2.194418                        1
# 46                         2.267932                        1
# 47                         2.307076                        3
# 48                              NaN                        0
# 49                         2.131579                        3
# 50                         2.226436                        4
# 51                         2.206871                       10
# 52                         2.209452                        5
# 53                         2.174564                        1
# 54                         2.027051                        5
# 55                         2.306695                        2
# 56                         2.308707                        2
# 57                         2.309696                        4
# 58                         2.150964                       15
# 59                         2.328467                        2
# 60                         2.300489                        1
# 61                         2.219976                       12
# 62                         2.172579                        8
# 63                         2.193386                       20
# 64                         2.068376                       22
# 65                         2.103648                       18
# 66                         2.215556                        1
# 67                         2.078358                        5
# 68                         2.251656                       10
# 69                         2.233514                        9
# 70                         2.142857                       12
# 71                         2.046270                        6
# 72                         2.037866                        1
# 73                         2.119724                        7
# 74                         2.147000                       14
# 75                         2.111831                        6
# 76                         2.210581                        2
# 77                         2.174684                        2
# 78                         2.090909                        6
# 79                         1.798748                        1
# 80                         2.145695                       11
# 81                         2.164781                        2
# 82                         2.262248                        3
# 83                         2.043192                        2
# 84                         2.228840                        6
# 85                         2.127458                        6
# 86                         2.151515                        4
# 87                         2.108090                        2
# 88                         2.179191                        5
# 89                         2.154057                       28
# 90                         2.225285                       13
# 91                         2.128305                        3
# 92                         2.226387                        3
# 93                         2.063964                       12
# 94                         2.145674                        5
# 95                         2.210435                        3
# 96                         2.114061                        6
# 97                         2.263547                        1
# 98                         2.118102                        4
# 99                         2.160279                        4
#
#     Average_Word_Length
# 0              5.361564
# 1              5.760229
# 2              6.207960
# 3              6.138174
# 4              5.946617
# 5              6.062678
# 6              5.746977
# 7              6.322261
# 8              6.283079
# 9              5.547916
# 10             6.028139
# 11             5.917761
# 12             5.952227
# 13             5.777778
# 14             5.804408
# 15             5.820111
# 16             5.903164
# 17             5.800392
# 18             5.650056
# 19             5.989885
# 20             5.996381
# 21             5.967862
# 22             5.563526
# 23             5.918597
# 24             5.473313
# 25             5.702047
# 26             5.254113
# 27             5.712092
# 28             5.888689
# 29             5.379149
# 30             5.734817
# 31             5.367874
# 32             5.457871
# 33             5.533006
# 34             5.797232
# 35             4.000000
# 36             5.661271
# 37             5.269846
# 38             5.426020
# 39             5.875354
# 40             5.552898
# 41             5.329319
# 42             5.522433
# 43             5.998599
# 44             5.267472
# 45             5.751613
# 46             5.998131
# 47             6.176329
# 48             4.000000
# 49             5.583082
# 50             5.735542
# 51             5.378096
# 52             5.921482
# 53             5.952636
# 54             5.462428
# 55             6.060447
# 56             6.103101
# 57             6.354226
# 58             5.615963
# 59             6.329325
# 60             5.981517
# 61             5.884189
# 62             5.557975
# 63             5.661993
# 64             5.273343
# 65             5.412732
# 66             5.475870
# 67             5.212291
# 68             5.815847
# 69             5.546182
# 70             5.452083
# 71             5.354947
# 72             5.583174
# 73             5.568958
# 74             5.454822
# 75             5.381584
# 76             5.802593
# 77             5.758345
# 78             5.484998
# 79             5.139588
# 80             5.463860
# 81             5.820809
# 82             6.199819
# 83             5.591143
# 84             5.377786
# 85             5.431466
# 86             5.643035
# 87             5.554164
# 88             5.658302
# 89             5.487932
# 90             5.571429
# 91             5.653932
# 92             5.983681
# 93             5.452967
# 94             5.781631
# 95             5.693501
# 96             5.444112
# 97             6.181327
# 98             5.784516
# 99             5.768887

# %% [markdown]
# # Creating and saving output file in the desired format

# %%
output_file = pd.concat([df, content], axis=1)

# %%
output_file.drop(columns = ['content','clean_text'],inplace = True)
output_file
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# 5   blackassign0006  https://insights.blackcoffer.com/the-rise-of-t...
# 6   blackassign0007  https://insights.blackcoffer.com/rise-of-cyber...
# 7   blackassign0008  https://insights.blackcoffer.com/rise-of-inter...
# 8   blackassign0009  https://insights.blackcoffer.com/rise-of-cyber...
# 9   blackassign0010  https://insights.blackcoffer.com/rise-of-cyber...
# 10  blackassign0011  https://insights.blackcoffer.com/rise-of-inter...
# 11  blackassign0012  https://insights.blackcoffer.com/rise-of-telem...
# 12  blackassign0013  https://insights.blackcoffer.com/rise-of-e-hea...
# 13  blackassign0014  https://insights.blackcoffer.com/rise-of-e-hea...
# 14  blackassign0015  https://insights.blackcoffer.com/rise-of-telem...
# 15  blackassign0016  https://insights.blackcoffer.com/rise-of-telem...
# 16  blackassign0017  https://insights.blackcoffer.com/rise-of-chatb...
# 17  blackassign0018  https://insights.blackcoffer.com/rise-of-e-hea...
# 18  blackassign0019  https://insights.blackcoffer.com/how-does-mark...
# 19  blackassign0020  https://insights.blackcoffer.com/how-advertise...
# 20  blackassign0021  https://insights.blackcoffer.com/negative-effe...
# 21  blackassign0022  https://insights.blackcoffer.com/how-advertise...
# 22  blackassign0023  https://insights.blackcoffer.com/rising-it-cit...
# 23  blackassign0024  https://insights.blackcoffer.com/rise-of-ott-p...
# 24  blackassign0025  https://insights.blackcoffer.com/rise-of-elect...
# 25  blackassign0026  https://insights.blackcoffer.com/rise-of-elect...
# 26  blackassign0027  https://insights.blackcoffer.com/oil-prices-by...
# 27  blackassign0028  https://insights.blackcoffer.com/an-outlook-of...
# 28  blackassign0029  https://insights.blackcoffer.com/ai-in-healthc...
# 29  blackassign0030  https://insights.blackcoffer.com/what-if-the-c...
# 30  blackassign0031  https://insights.blackcoffer.com/what-jobs-wil...
# 31  blackassign0032  https://insights.blackcoffer.com/will-machine-...
# 32  blackassign0033  https://insights.blackcoffer.com/will-ai-repla...
# 33  blackassign0034  https://insights.blackcoffer.com/man-and-machi...
# 34  blackassign0035  https://insights.blackcoffer.com/in-future-or-...
# 35  blackassign0036  https://insights.blackcoffer.com/how-neural-ne...
# 36  blackassign0037  https://insights.blackcoffer.com/how-machine-l...
# 37  blackassign0038  https://insights.blackcoffer.com/deep-learning...
# 38  blackassign0039  https://insights.blackcoffer.com/how-to-protec...
# 39  blackassign0040  https://insights.blackcoffer.com/how-machines-...
# 40  blackassign0041  https://insights.blackcoffer.com/ai-human-robo...
# 41  blackassign0042  https://insights.blackcoffer.com/how-ai-will-c...
# 42  blackassign0043  https://insights.blackcoffer.com/future-of-wor...
# 43  blackassign0044  https://insights.blackcoffer.com/ai-tool-alexa...
# 44  blackassign0045  https://insights.blackcoffer.com/ai-healthcare...
# 45  blackassign0046  https://insights.blackcoffer.com/all-you-need-...
# 46  blackassign0047  https://insights.blackcoffer.com/evolution-of-...
# 47  blackassign0048  https://insights.blackcoffer.com/how-data-anal...
# 48  blackassign0049  https://insights.blackcoffer.com/covid-19-envi...
# 49  blackassign0050  https://insights.blackcoffer.com/environmental...
# 50  blackassign0051  https://insights.blackcoffer.com/how-data-anal...
# 51  blackassign0052  https://insights.blackcoffer.com/difference-be...
# 52  blackassign0053  https://insights.blackcoffer.com/how-python-be...
# 53  blackassign0054  https://insights.blackcoffer.com/how-google-fi...
# 54  blackassign0055  https://insights.blackcoffer.com/what-is-the-f...
# 55  blackassign0056  https://insights.blackcoffer.com/impact-of-ai-...
# 56  blackassign0057  https://insights.blackcoffer.com/telemedicine-...
# 57  blackassign0058  https://insights.blackcoffer.com/how-we-foreca...
# 58  blackassign0059  https://insights.blackcoffer.com/can-robots-ta...
# 59  blackassign0060  https://insights.blackcoffer.com/embedding-car...
# 60  blackassign0061  https://insights.blackcoffer.com/management-ch...
# 61  blackassign0062  https://insights.blackcoffer.com/are-we-any-cl...
# 62  blackassign0063  https://insights.blackcoffer.com/will-technolo...
# 63  blackassign0064  https://insights.blackcoffer.com/will-we-ever-...
# 64  blackassign0065  https://insights.blackcoffer.com/will-we-ever-...
# 65  blackassign0066  https://insights.blackcoffer.com/what-is-the-c...
# 66  blackassign0067  https://insights.blackcoffer.com/why-does-your...
# 67  blackassign0068  https://insights.blackcoffer.com/how-you-lead-...
# 68  blackassign0069  https://insights.blackcoffer.com/can-you-be-gr...
# 69  blackassign0070  https://insights.blackcoffer.com/how-does-arti...
# 70  blackassign0071  https://insights.blackcoffer.com/how-to-overco...
# 71  blackassign0072  https://insights.blackcoffer.com/is-perfection...
# 72  blackassign0073  https://insights.blackcoffer.com/global-financ...
# 73  blackassign0074  https://insights.blackcoffer.com/gender-divers...
# 74  blackassign0075  https://insights.blackcoffer.com/how-to-overco...
# 75  blackassign0076  https://insights.blackcoffer.com/how-small-bus...
# 76  blackassign0077  https://insights.blackcoffer.com/impacts-of-co...
# 77  blackassign0078  https://insights.blackcoffer.com/impacts-of-co...
# 78  blackassign0079  https://insights.blackcoffer.com/impact-of-cov...
# 79  blackassign0080  https://insights.blackcoffer.com/impact-of-cov...
# 80  blackassign0081  https://insights.blackcoffer.com/changing-land...
# 81  blackassign0082  https://insights.blackcoffer.com/online-gaming...
# 82  blackassign0083  https://insights.blackcoffer.com/human-rights-...
# 83  blackassign0084  https://insights.blackcoffer.com/how-voice-sea...
# 84  blackassign0085  https://insights.blackcoffer.com/how-the-covid...
# 85  blackassign0086  https://insights.blackcoffer.com/how-to-increa...
# 86  blackassign0087  https://insights.blackcoffer.com/impacts-of-co...
# 87  blackassign0088  https://insights.blackcoffer.com/coronavirus-i...
# 88  blackassign0089  https://insights.blackcoffer.com/coronavirus-i...
# 89  blackassign0090  https://insights.blackcoffer.com/lessons-from-...
# 90  blackassign0091  https://insights.blackcoffer.com/estimating-th...
# 91  blackassign0092  https://insights.blackcoffer.com/estimating-th...
# 92  blackassign0093  https://insights.blackcoffer.com/travel-and-to...
# 93  blackassign0094  https://insights.blackcoffer.com/gaming-disord...
# 94  blackassign0095  https://insights.blackcoffer.com/what-is-the-r...
# 95  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 96  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 97  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 98  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 99  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
#     Positive_Score  Negative_score  Polarity_Score  Subjectivity_Score  \
# 0               61              10        0.718310            0.064195
# 1               83              34        0.418803            0.089381
# 2               68              26        0.446809            0.077049
# 3               68              80       -0.081081            0.123128
# 4               51              12        0.619048            0.067236
# 5              119              30        0.597315            0.090965
# 6               64              73       -0.065693            0.108044
# 7               62              13        0.653333            0.068807
# 8               68              56        0.096774            0.104377
# 9              160             184       -0.069767            0.150350
# 10              92              23        0.600000            0.082437
# 11             115              27        0.619718            0.097931
# 12              73              18        0.604396            0.102132
# 13              56              30        0.302326            0.074394
# 14              70              30        0.400000            0.080906
# 15              69              30        0.393939            0.080097
# 16              90              14        0.730769            0.088285
# 17              65              13        0.666667            0.067650
# 18              91               9        0.820000            0.070721
# 19              40               3        0.860465            0.051621
# 20              53              52        0.009524            0.094595
# 21              45              15        0.500000            0.077720
# 22              62              19        0.530864            0.068297
# 23              54               6        0.800000            0.067797
# 24              48              13        0.573770            0.058317
# 25              54              18        0.500000            0.067733
# 26              55              29        0.309524            0.072853
# 27              68              29        0.402062            0.084495
# 28             102              35        0.489051            0.085840
# 29              92              40        0.393939            0.114385
# 30              99              39        0.434783            0.096167
# 31             102              33        0.511111            0.107741
# 32              95              29        0.532258            0.089920
# 33              79              26        0.504762            0.090595
# 34              59              14        0.616438            0.077825
# 35               0               0        0.000000            0.000000
# 36              66              16        0.609756            0.088267
# 37              96              36        0.454545            0.086899
# 38              87              60        0.183673            0.094839
# 39              67              28        0.410526            0.080304
# 40              61              35        0.270833            0.080944
# 41              90              27        0.538462            0.092857
# 42             102              24        0.619048            0.092852
# 43              58               4        0.870968            0.073286
# 44             110              43        0.437908            0.119438
# 45              58               6        0.812500            0.061598
# 46              48               9        0.684211            0.060127
# 47              38               7        0.688889            0.060080
# 48               0               0        0.000000            0.000000
# 49              58              73       -0.114504            0.104466
# 50              49              17        0.484848            0.071506
# 51              94              41        0.392593            0.098684
# 52              77               6        0.855422            0.089151
# 53              37               3        0.850000            0.049875
# 54              59              13        0.638889            0.062827
# 55              61              12        0.671233            0.078834
# 56              49              14        0.555556            0.083113
# 57              38               5        0.767442            0.062229
# 58              55              42        0.134021            0.103854
# 59              40               8        0.666667            0.070073
# 60              81              23        0.557692            0.084691
# 61              43              24        0.283582            0.079667
# 62              57              41        0.163265            0.093960
# 63              60              52        0.071429            0.080518
# 64              78              26        0.500000            0.080808
# 65              63              28        0.384615            0.075456
# 66              59              12        0.661972            0.078889
# 67              78              12        0.733333            0.083955
# 68              64              10        0.729730            0.098013
# 69              72              19        0.582418            0.070597
# 70              58              80       -0.159420            0.140816
# 71             100              30        0.538462            0.122757
# 72              60              49        0.100917            0.093804
# 73              62              31        0.333333            0.071374
# 74              56              87       -0.216783            0.143000
# 75              71              40        0.279279            0.089951
# 76              55              16        0.549296            0.073651
# 77              67              27        0.425532            0.079325
# 78              64              51        0.113043            0.084311
# 79              66              18        0.571429            0.037567
# 80              68              45        0.203540            0.083149
# 81              61              75       -0.102941            0.096181
# 82              37               6        0.720930            0.061960
# 83              64               8        0.777778            0.067606
# 84              72              36        0.333333            0.084639
# 85              86              23        0.577982            0.079388
# 86              62              38        0.240000            0.091827
# 87              52              44        0.083333            0.065262
# 88              50              45        0.052632            0.091522
# 89              67              54        0.107438            0.110301
# 90              57              31        0.295455            0.083650
# 91              61              47        0.129630            0.083981
# 92              34               7        0.658537            0.061469
# 93              65              52        0.111111            0.105405
# 94              41              28        0.188406            0.075575
# 95              58              57        0.008696            0.100000
# 96              55              38        0.182796            0.091445
# 97              41               6        0.744681            0.057882
# 98              49               6        0.781818            0.060706
# 99              72              62        0.074627            0.116725
#
#     Average_Sentence_Length  Percentage_of_Complex_Words  Fog_Index  \
# 0                 23.615385                    96.925859  48.216497
# 1                 25.195876                    97.249809  48.978274
# 2                 28.714286                    97.295082  50.403747
# 3                 31.476190                    97.587354  51.625418
# 4                 29.833333                    96.905016  50.695340
# 5                 26.742857                    97.130647  49.549402
# 6                 25.375000                    96.687697  48.825079
# 7                 28.600000                    95.412844  49.605138
# 8                 25.635135                    96.885522  49.008263
# 9                 18.395257                    98.470280  46.746215
# 10                28.686747                    97.347670  50.413767
# 11                28.777778                    97.862069  50.655939
# 12                43.027778                    96.745230  55.909203
# 13                26.883117                    96.453287  49.334562
# 14                30.250000                    96.925566  50.870227
# 15                31.420290                    96.844660  51.305980
# 16                27.090909                    96.859083  49.579997
# 17                36.410714                    96.617520  53.211294
# 18                24.263636                    97.312588  48.630490
# 19                38.025641                    95.798319  53.529584
# 20                31.193548                    97.027027  51.288230
# 21                31.116279                    95.984456  50.840294
# 22                30.051948                    96.964587  50.806614
# 23                47.218750                    95.819209  57.215184
# 24                56.742857                    95.315488  60.823338
# 25                33.142857                    95.202258  51.338046
# 26                33.478261                    95.576756  51.622007
# 27                38.592593                    96.341463  53.973622
# 28                31.908046                    97.117794  51.610336
# 29                25.000000                    96.620451  48.648180
# 30                25.990196                    97.560976  49.420469
# 31                23.387387                    97.126895  48.205713
# 32                29.096774                    97.099347  50.478449
# 33                28.025000                    96.980155  50.002062
# 34                27.245902                    95.842217  49.235248
# 35                 1.000000                     0.000000   0.400000
# 36                32.705882                    96.124865  51.532299
# 37                31.555556                    97.498354  51.621564
# 38                24.725000                    97.612903  48.935161
# 39                29.830986                    97.379544  50.884212
# 40                22.645833                    96.711636  47.742988
# 41                38.507246                    96.587302  54.037819
# 42                28.279570                    96.315402  49.837989
# 43                39.666667                    96.453901  54.448227
# 44               105.115385                    96.643247  80.703453
# 45                27.352941                    97.016362  49.747721
# 46                30.865385                    96.518987  50.953749
# 47                49.680000                    95.861148  58.216459
# 48                 1.000000                     0.000000   0.400000
# 49                33.579710                    97.288676  52.347355
# 50                40.487805                    95.991333  54.591655
# 51                22.753968                    97.368421  48.048956
# 52                28.428571                    96.240602  49.867669
# 53                40.906250                    96.259352  54.866241
# 54                31.454545                    96.073298  51.011138
# 55                43.485714                    96.328294  55.925603
# 56                30.000000                    95.646438  50.258575
# 57                45.782609                    95.803184  56.634317
# 58                24.700000                    96.895075  48.638030
# 59                45.041667                    95.474453  56.206448
# 60                30.579710                    96.498371  50.831233
# 61                43.696970                    96.195006  55.956790
# 62                29.924242                    96.644295  50.627415
# 63                29.651685                    97.627606  50.911717
# 64                32.390244                    97.047397  51.775056
# 65                24.204082                    96.766169  48.388100
# 66                23.142857                    95.444444  47.434921
# 67                30.220779                    97.014925  50.894282
# 68                48.678571                    96.158940  57.935005
# 69                30.132530                    97.284717  50.966899
# 70                22.068966                    96.938776  47.603096
# 71                22.148936                    96.883853  47.613116
# 72                40.230769                    96.815835  54.818642
# 73                27.252874                    95.395242  49.059246
# 74                21.413043                    96.800000  47.285217
# 75                37.119403                    96.758509  53.551165
# 76                48.485714                    96.473029  57.983497
# 77                42.540000                    96.877637  55.767055
# 78                31.345238                    96.920821  51.306424
# 79                17.550201                    93.425760  44.390384
# 80                27.670103                    96.688742  49.743538
# 81                34.112676                    97.312588  52.570106
# 82                58.210526                    95.100865  61.324556
# 83                33.482759                    94.460094  51.177141
# 84                20.578947                    97.570533  47.259792
# 85                25.129630                    97.450838  49.032187
# 86                34.534483                    96.510560  52.418017
# 87                38.771429                    95.853161  53.849836
# 88                31.216667                    96.146435  50.945241
# 89                25.154762                    97.356427  49.004475
# 90                42.893617                    96.768061  55.864671
# 91                38.810345                    95.256610  53.626782
# 92                47.956522                    95.052474  57.203598
# 93                25.280488                    97.027027  48.923006
# 94                31.775510                    95.618839  50.957740
# 95                33.803279                    96.956522  52.303920
# 96                39.294118                    96.361849  54.262386
# 97                64.800000                    95.812808  64.245123
# 98                37.804878                    94.591611  52.958596
# 99                46.790698                    96.428571  57.287708
#
#     Average_Number_of_Words_Per_Sentence  Complex_Word_Count  Word_Count  \
# 0                              12.153846                1072        1106
# 1                              13.494845                1273        1309
# 2                              17.428571                1187        1220
# 3                              19.079365                1173        1202
# 4                              17.351852                 908         937
# 5                              15.600000                1591        1638
# 6                              14.409091                1226        1268
# 7                              18.166667                1040        1090
# 8                              16.054054                1151        1188
# 9                               9.043478                2253        2288
# 10                             16.807229                1358        1395
# 11                             16.111111                1419        1450
# 12                             24.750000                 862         891
# 13                             15.012987                1115        1156
# 14                             17.166667                1198        1236
# 15                             17.913043                1197        1236
# 16                             15.298701                1141        1178
# 17                             20.589286                1114        1153
# 18                             12.854545                1376        1414
# 19                             21.358974                 798         833
# 20                             17.903226                1077        1110
# 21                             17.953488                 741         772
# 22                             15.402597                1150        1186
# 23                             27.656250                 848         885
# 24                             29.885714                 997        1046
# 25                             18.982143                1012        1063
# 26                             16.710145                1102        1153
# 27                             21.259259                1106        1148
# 28                             18.344828                1550        1596
# 29                             12.276596                1115        1154
# 30                             14.068627                1400        1435
# 31                             11.288288                1217        1253
# 32                             14.827957                1339        1379
# 33                             14.487500                1124        1159
# 34                             15.377049                 899         938
# 35                              0.000000                   0           0
# 36                             18.215686                 893         929
# 37                             15.343434                1481        1519
# 38                             12.916667                1513        1550
# 39                             16.661972                1152        1183
# 40                             12.354167                1147        1186
# 41                             18.260870                1217        1260
# 42                             14.591398                1307        1357
# 43                             23.500000                 816         846
# 44                             49.269231                1238        1281
# 45                             15.279412                1008        1039
# 46                             18.230769                 915         948
# 47                             29.960000                 718         749
# 48                              0.000000                   0           0
# 49                             18.173913                1220        1254
# 50                             22.512195                 886         923
# 51                             10.857143                1332        1368
# 52                             16.625000                 896         931
# 53                             25.062500                 772         802
# 54                             17.363636                1101        1146
# 55                             26.457143                 892         926
# 56                             17.627907                 725         758
# 57                             30.043478                 662         691
# 58                             13.342857                 905         934
# 59                             28.541667                 654         685
# 60                             17.797101                1185        1228
# 61                             25.484848                 809         841
# 62                             15.803030                1008        1043
# 63                             15.629213                1358        1391
# 64                             15.695122                1249        1287
# 65                             12.306122                1167        1206
# 66                             11.688312                 859         900
# 67                             13.922078                1040        1072
# 68                             26.964286                 726         755
# 69                             15.530120                1254        1289
# 70                             11.264368                 950         980
# 71                             11.265957                1026        1059
# 72                             22.346154                1125        1162
# 73                             14.977011                1243        1303
# 74                             10.869565                 968        1000
# 75                             18.417910                1194        1234
# 76                             27.542857                 930         964
# 77                             23.700000                1148        1185
# 78                             16.238095                1322        1364
# 79                              8.979920                2089        2236
# 80                             14.010309                1314        1359
# 81                             19.915493                1376        1414
# 82                             36.526316                 660         694
# 83                             18.362069                1006        1065
# 84                              9.593985                1245        1276
# 85                             12.712963                1338        1373
# 86                             18.775862                1051        1089
# 87                             21.014286                1410        1471
# 88                             17.300000                 998        1038
# 89                             13.059524                1068        1097
# 90                             22.382979                1018        1052
# 91                             22.172414                1225        1286
# 92                             29.000000                 634         667
# 93                             13.536585                1077        1110
# 94                             18.632653                 873         913
# 95                             18.852459                1115        1150
# 96                             19.941176                 980        1017
# 97                             40.600000                 778         812
# 98                             22.097561                 857         906
# 99                             26.697674                1107        1148
#
#     Average_Syllable_Count_Per_Word  Personal_Pronouns_Count  \
# 0                          2.120253                        7
# 1                          2.266616                        4
# 2                          2.380328                       15
# 3                          2.306988                        5
# 4                          2.228388                        8
# 5                          2.282051                        7
# 6                          2.165615                        2
# 7                          2.369725                        4
# 8                          2.351010                        4
# 9                          2.277098                       14
# 10                         2.315412                        3
# 11                         2.322759                        3
# 12                         2.300786                        4
# 13                         2.202422                        4
# 14                         2.165858                        8
# 15                         2.169903                        7
# 16                         2.220713                        6
# 17                         2.235906                        2
# 18                         2.219236                        5
# 19                         2.264106                        2
# 20                         2.292793                        8
# 21                         2.266839                        5
# 22                         2.197302                        9
# 23                         2.220339                        2
# 24                         2.083174                        5
# 25                         2.149577                        3
# 26                         2.044232                       20
# 27                         2.185540                        8
# 28                         2.246867                        2
# 29                         2.171577                        7
# 30                         2.278746                        3
# 31                         2.167598                       18
# 32                         2.172589                       13
# 33                         2.172563                       19
# 34                         2.224947                        8
# 35                              NaN                        0
# 36                         2.133477                        3
# 37                         2.173799                       10
# 38                         2.078710                        3
# 39                         2.309383                        9
# 40                         2.163575                        7
# 41                         2.261905                       34
# 42                         2.155490                       12
# 43                         2.275414                        1
# 44                         2.126464                       17
# 45                         2.194418                        1
# 46                         2.267932                        1
# 47                         2.307076                        3
# 48                              NaN                        0
# 49                         2.131579                        3
# 50                         2.226436                        4
# 51                         2.206871                       10
# 52                         2.209452                        5
# 53                         2.174564                        1
# 54                         2.027051                        5
# 55                         2.306695                        2
# 56                         2.308707                        2
# 57                         2.309696                        4
# 58                         2.150964                       15
# 59                         2.328467                        2
# 60                         2.300489                        1
# 61                         2.219976                       12
# 62                         2.172579                        8
# 63                         2.193386                       20
# 64                         2.068376                       22
# 65                         2.103648                       18
# 66                         2.215556                        1
# 67                         2.078358                        5
# 68                         2.251656                       10
# 69                         2.233514                        9
# 70                         2.142857                       12
# 71                         2.046270                        6
# 72                         2.037866                        1
# 73                         2.119724                        7
# 74                         2.147000                       14
# 75                         2.111831                        6
# 76                         2.210581                        2
# 77                         2.174684                        2
# 78                         2.090909                        6
# 79                         1.798748                        1
# 80                         2.145695                       11
# 81                         2.164781                        2
# 82                         2.262248                        3
# 83                         2.043192                        2
# 84                         2.228840                        6
# 85                         2.127458                        6
# 86                         2.151515                        4
# 87                         2.108090                        2
# 88                         2.179191                        5
# 89                         2.154057                       28
# 90                         2.225285                       13
# 91                         2.128305                        3
# 92                         2.226387                        3
# 93                         2.063964                       12
# 94                         2.145674                        5
# 95                         2.210435                        3
# 96                         2.114061                        6
# 97                         2.263547                        1
# 98                         2.118102                        4
# 99                         2.160279                        4
#
#     Average_Word_Length
# 0              5.361564
# 1              5.760229
# 2              6.207960
# 3              6.138174
# 4              5.946617
# 5              6.062678
# 6              5.746977
# 7              6.322261
# 8              6.283079
# 9              5.547916
# 10             6.028139
# 11             5.917761
# 12             5.952227
# 13             5.777778
# 14             5.804408
# 15             5.820111
# 16             5.903164
# 17             5.800392
# 18             5.650056
# 19             5.989885
# 20             5.996381
# 21             5.967862
# 22             5.563526
# 23             5.918597
# 24             5.473313
# 25             5.702047
# 26             5.254113
# 27             5.712092
# 28             5.888689
# 29             5.379149
# 30             5.734817
# 31             5.367874
# 32             5.457871
# 33             5.533006
# 34             5.797232
# 35             4.000000
# 36             5.661271
# 37             5.269846
# 38             5.426020
# 39             5.875354
# 40             5.552898
# 41             5.329319
# 42             5.522433
# 43             5.998599
# 44             5.267472
# 45             5.751613
# 46             5.998131
# 47             6.176329
# 48             4.000000
# 49             5.583082
# 50             5.735542
# 51             5.378096
# 52             5.921482
# 53             5.952636
# 54             5.462428
# 55             6.060447
# 56             6.103101
# 57             6.354226
# 58             5.615963
# 59             6.329325
# 60             5.981517
# 61             5.884189
# 62             5.557975
# 63             5.661993
# 64             5.273343
# 65             5.412732
# 66             5.475870
# 67             5.212291
# 68             5.815847
# 69             5.546182
# 70             5.452083
# 71             5.354947
# 72             5.583174
# 73             5.568958
# 74             5.454822
# 75             5.381584
# 76             5.802593
# 77             5.758345
# 78             5.484998
# 79             5.139588
# 80             5.463860
# 81             5.820809
# 82             6.199819
# 83             5.591143
# 84             5.377786
# 85             5.431466
# 86             5.643035
# 87             5.554164
# 88             5.658302
# 89             5.487932
# 90             5.571429
# 91             5.653932
# 92             5.983681
# 93             5.452967
# 94             5.781631
# 95             5.693501
# 96             5.444112
# 97             6.181327
# 98             5.784516
# 99             5.768887

# %%
output_file.to_excel(Output_File_Location, index = False)
